# %%
import csv
import numpy as np
import pandas as pd
from collections import Counter
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.tokenize import WordPunctTokenizer
from nltk.stem.porter import *
from nltk.stem.snowball import SnowballStemmer
from nltk.collocations import BigramCollocationFinder
from nltk.metrics import BigramAssocMeasures

# %%
data = open('6334229.txt', 'r')
data.read()
# Out:
# '~~ 1. A scrubber for scrubbing a semiconductor wafer having an edge, comprising: a first roller for cleaning an edge of the semiconductor wafer, and  a second roller for rotating the semiconductor wafer, the first roller being configured to rotate in a direction at a first speed and the second roller being configured to rotate in the direction at a second speed so as to facilitate an edge cleaning of the semiconductor wafer by the first roller, the edge of the semiconductor wafer is cleaned due to friction from a difference in tangential velocity at a point of contact between the semiconductor wafer and the first roller.  2. The scrubber defined in  claim 1  wherein the mechanism edge cleans particles from a bevel area of the semiconductor wafer. 3. The scrubber defined in  claim 1  wherein the edge of the semiconductor wafer is cleaned due to friction between the edge and an abrasive material. 4. The scrubber defined in  claim 1  wherein the first roller comprises an abrasive material. 5. The scrubber defined in  claim 4  wherein the second speed is faster than the first speed. 6. The scrubber defined in  claim 5  wherein the second speed is approximately 1.5 times the first speed. 7. The scrubber defined in  claim 4  wherein the cleaning mechanism further comprises a water jet propelling water at an area of contact between the semiconductor wafer and the first roller. 8. The scrubber defined in  claim 1  wherein the second roller comprises an abrasive material. 9. The scrubber defined in  claim 8  wherein the abrasive material comprises a pad. 10. The scrubber defined in  claim 8  wherein the abrasive material comprises poly vinyl alcohol (PVA). 11. The scrubber defined in  claim 8  wherein the abrasive material comprises nylon. 12. The scrubber defined in  claim 8  wherein the abrasive material comprises polyurethane. 13. A scrubber for scrubbing a semiconductor wafer having an edge, comprising: a first roller for clearing an edge of the semiconductor wafer; and  a second roller for rotating the semiconductor wafer, the first roller being configured to rotate in a direction at a first speed and the second roller being configured to rotate in the direction at a second speed so as to facilitate an edge cleaning of the semiconductor wafer by the first roller by generating friction between the edge and an abrasive material on the first roller.  14. The scrubber defined in  claim 13  wherein the mechanism edge cleans particles from a bevel area of the semiconductor wafer. 15. The scrubber defined in  claim 13  wherein the abrasive material comprises poly vinyl alcohol (PVA). 16. The scrubber defined in  claim 13  wherein the abrasive material comprises nylon. 17. The scrubber defined in  claim 13  wherein the abrasive material comprises polyurethane. 18. A scrubbing apparatus for cleaning a semiconductor substrate with an edge, said apparatus comprising: a first roller that rotates the semiconductor substrate at a first speed; and  a second roller that rotates in a same direction as the first roller at a second speed different than the first speed and contacts the edge of the semiconductor substrate when the edge is cleaned due to a difference in tangential velocity at a point of contact between the semiconductor substrate and the second roller.  19. The apparatus defined in  claim 18  wherein the semiconductor substrate further includes at least one bevel area, and the second roller cleans said at least one bevel area due to the difference in tangential velocity. 20. The apparatus defined in  claim 18  wherein the second roller comprises an abrasive material. 21. The apparatus defined in  claim 20  wherein the abrasive material comprises a pad. 22. The apparatus defined in  claim 20  wherein the abrasive material comprises poly vinyl alcohol (PVA). 23. The apparatus defined in  claim 20  wherein the abrasive material comprises nylon. 24. The apparatus defined in  claim 20  wherein the abrasive material comprises polyurethane.  ...

# %%
#TAKE OUT STOP WORDS
stopset = set(stopwords.words('english'))

with open('6334229.txt', 'r') as text_file:
    text = text_file.read()
    tokens = nltk.word_tokenize(str(text))
    tokens = [w for w in tokens if not w in stopset]
    print tokens
# Out:
# ['~~', '1', '.', 'A', 'scrubber', 'scrubbing', 'semiconductor', 'wafer', 'edge', ',', 'comprising', ':', 'first', 'roller', 'cleaning', 'edge', 'semiconductor', 'wafer', ',', 'second', 'roller', 'rotating', 'semiconductor', 'wafer', ',', 'first', 'roller', 'configured', 'rotate', 'direction', 'first', 'speed', 'second', 'roller', 'configured', 'rotate', 'direction', 'second', 'speed', 'facilitate', 'edge', 'cleaning', 'semiconductor', 'wafer', 'first', 'roller', ',', 'edge', 'semiconductor', 'wafer', 'cleaned', 'due', 'friction', 'difference', 'tangential', 'velocity', 'point', 'contact', 'semiconductor', 'wafer', 'first', 'roller', '.', '2', '.', 'The', 'scrubber', 'defined', 'claim', '1', 'wherein', 'mechanism', 'edge', 'cleans', 'particles', 'bevel', 'area', 'semiconductor', 'wafer', '.', '3', '.', 'The', 'scrubber', 'defined', 'claim', '1', 'wherein', 'edge', 'semiconductor', 'wafer', 'cleaned', 'due', 'friction', 'edge', 'abrasive', 'material', '.', '4', '.', 'The', 'scrubber', 'defined', 'claim', '1', 'wherein', 'first', 'roller', 'comprises', 'abrasive', 'material', '.', '5', '.', 'The', 'scrubber', 'defined', 'claim', '4', 'wherein', 'second', 'speed', 'faster', 'first', 'speed', '.', '6', '.', 'The', 'scrubber', 'defined', 'claim', '5', 'wherein', 'second', 'speed', 'approximately', '1.5', 'times', 'first', 'speed', '.', '7', '.', 'The', 'scrubber', 'defined', 'claim', '4', 'wherein', 'cleaning', 'mechanism', 'comprises', 'water', 'jet', 'propelling', 'water', 'area', 'contact', 'semiconductor', 'wafer', 'first', 'roller', '.', '8', '.', 'The', 'scrubber', 'defined', 'claim', '1', 'wherein', 'second', 'roller', 'comprises', 'abrasive', 'material', '.', '9', '.', 'The', 'scrubber', 'defined', 'claim', '8', 'wherein', 'abrasive', 'material', 'comprises', 'pad', '.', '10', '.', 'The', 'scrubber', 'defined', 'claim', '8', 'wherein', 'abrasive', 'material', 'comprises', 'poly', 'vinyl', 'alcohol', '(', 'PVA', ')', '.', '11', '.', 'The', 'scrubber', 'defined', 'claim', '8', 'wherein', 'abrasive', 'material', 'comprises', 'nylon', '.', '12', '.', 'The', 'scrubber', 'defined', 'claim', '8', 'wherein', 'abrasive', 'material', 'comprises', 'polyurethane', '.', '13', '.', 'A', 'scrubber', 'scrubbing', 'semiconductor', 'wafer', 'edge', ',', 'comprising', ':', 'first', 'roller', 'clearing', 'edge', 'semiconductor', 'wafer', ';', 'second', 'roller', 'rotating', 'semiconductor', 'wafer', ',', 'first', 'roller', 'configured', 'rotate', 'direction', 'first', 'speed', 'second', 'roller', 'configured', 'rotate', 'direction', 'second', 'speed', 'facilitate', 'edge', 'cleaning', 'semiconductor', 'wafer', 'first', 'roller', 'generating', 'friction', 'edge', 'abrasive', 'material', 'first', 'roller', '.', '14', '.', 'The', 'scrubber', 'defined', 'claim', '13', 'wherein', 'mechanism', 'edge', 'cleans', 'particles', 'bevel', 'area', 'semiconductor', 'wafer', '.', '15', '.', 'The', 'scrubber', 'defined', 'claim', '13', 'wherein', 'abrasive', 'material', 'comprises', 'poly', 'vinyl', 'alcohol', '(', 'PVA', ')', '.', '16', '.', 'The', 'scrubber', 'defined', 'claim', '13', 'wherein', 'abrasive', 'material', 'comprises', 'nylon', '.', '17', '.', 'The', 'scrubber', 'defined', 'claim', '13', 'wherein', 'abrasive', 'material', 'comprises', 'polyurethane', '.', '18', '.', 'A', 'scrubbing', 'apparatus', 'cleaning', 'semiconductor', 'substrate', 'edge', ',', 'said', 'apparatus', 'comprising', ':', 'first', 'roller', 'rotates', 'semiconductor', 'substrate', 'first', 'speed', ';', 'second', 'roller', 'rotates', 'direction', 'first', 'roller', 'second', 'speed', 'different', 'first', 'speed', 'contacts', 'edge', 'semiconductor', 'substrate', 'edge', 'cleaned', 'due', 'difference', 'tangential', 'velocity', 'point', 'contact', 'semiconductor', 'substrate', 'second', 'roller', '.', '19', '.', 'The', 'apparatus', 'defined', 'claim', '18', 'wherein', 'semiconductor', 'substrate', 'includes', 'least', 'one', 'bevel', 'area', ',', 'second', 'roller', 'cleans', ' ...

# %%
#STEM 1 TXT FILE for unigrams
stemmer = PorterStemmer()
stemmed = []
text = tokens
for word in text:
    stemmed.append(stemmer.stem(word))
print stemmed
# Out:
# [u'~~', u'1', u'.', u'A', u'scrubber', u'scrub', u'semiconductor', u'wafer', u'edg', u',', u'compris', u':', u'first', u'roller', u'clean', u'edg', u'semiconductor', u'wafer', u',', u'second', u'roller', u'rotat', u'semiconductor', u'wafer', u',', u'first', u'roller', u'configur', u'rotat', u'direct', u'first', u'speed', u'second', u'roller', u'configur', u'rotat', u'direct', u'second', u'speed', u'facilit', u'edg', u'clean', u'semiconductor', u'wafer', u'first', u'roller', u',', u'edg', u'semiconductor', u'wafer', u'clean', u'due', u'friction', u'differ', u'tangenti', u'veloc', u'point', u'contact', u'semiconductor', u'wafer', u'first', u'roller', u'.', u'2', u'.', u'The', u'scrubber', u'defin', u'claim', u'1', u'wherein', u'mechan', u'edg', u'clean', u'particl', u'bevel', u'area', u'semiconductor', u'wafer', u'.', u'3', u'.', u'The', u'scrubber', u'defin', u'claim', u'1', u'wherein', u'edg', u'semiconductor', u'wafer', u'clean', u'due', u'friction', u'edg', u'abras', u'materi', u'.', u'4', u'.', u'The', u'scrubber', u'defin', u'claim', u'1', u'wherein', u'first', u'roller', u'compris', u'abras', u'materi', u'.', u'5', u'.', u'The', u'scrubber', u'defin', u'claim', u'4', u'wherein', u'second', u'speed', u'faster', u'first', u'speed', u'.', u'6', u'.', u'The', u'scrubber', u'defin', u'claim', u'5', u'wherein', u'second', u'speed', u'approxim', u'1.5', u'time', u'first', u'speed', u'.', u'7', u'.', u'The', u'scrubber', u'defin', u'claim', u'4', u'wherein', u'clean', u'mechan', u'compris', u'water', u'jet', u'propel', u'water', u'area', u'contact', u'semiconductor', u'wafer', u'first', u'roller', u'.', u'8', u'.', u'The', u'scrubber', u'defin', u'claim', u'1', u'wherein', u'second', u'roller', u'compris', u'abras', u'materi', u'.', u'9', u'.', u'The', u'scrubber', u'defin', u'claim', u'8', u'wherein', u'abras', u'materi', u'compris', u'pad', u'.', u'10', u'.', u'The', u'scrubber', u'defin', u'claim', u'8', u'wherein', u'abras', u'materi', u'compris', u'poli', u'vinyl', u'alcohol', u'(', u'PVA', u')', u'.', u'11', u'.', u'The', u'scrubber', u'defin', u'claim', u'8', u'wherein', u'abras', u'materi', u'compris', u'nylon', u'.', u'12', u'.', u'The', u'scrubber', u'defin', u'claim', u'8', u'wherein', u'abras', u'materi', u'compris', u'polyurethan', u'.', u'13', u'.', u'A', u'scrubber', u'scrub', u'semiconductor', u'wafer', u'edg', u',', u'compris', u':', u'first', u'roller', u'clear', u'edg', u'semiconductor', u'wafer', u';', u'second', u'roller', u'rotat', u'semiconductor', u'wafer', u',', u'first', u'roller', u'configur', u'rotat', u'direct', u'first', u'speed', u'second', u'roller', u'configur', u'rotat', u'direct', u'second', u'speed', u'facilit', u'edg', u'clean', u'semiconductor', u'wafer', u'first', u'roller', u'gener', u'friction', u'edg', u'abras', u'materi', u'first', u'roller', u'.', u'14', u'.', u'The', u'scrubber', u'defin', u'claim', u'13', u'wherein', u'mechan', u'edg', u'clean', u'particl', u'bevel', u'area', u'semiconductor', u'wafer', u'.', u'15', u'.', u'The', u'scrubber', u'defin', u'claim', u'13', u'wherein', u'abras', u'materi', u'compris', u'poli', u'vinyl', u'alcohol', u'(', u'PVA', u')', u'.', u'16', u'.', u'The', u'scrubber', u'defin', u'claim', u'13', u'wherein', u'abras', u'materi', u'compris', u'nylon', u'.', u'17', u'.', u'The', u'scrubber', u'defin', u'claim', u'13', u'wherein', u'abras', u'materi', u'compris', u'polyurethan', u'.', u'18', u'.', u'A', u'scrub', u'apparatu', u'clean', u'semiconductor', u'substrat', u'edg', u',', u'said', u'apparatu', u'compris', u':', u'first', u'roller', u'rotat', u'semiconductor', u'substrat', u'first', u'speed', u';', u'second', u'roller', u'rotat', u'direct', u'first', u'roller', u'second', u'speed', u'differ', u'first', u'speed', u'contact', u'edg', u'semiconductor', u'substrat', u'edg', u'clean', u'due', u'differ', u'tangenti', u'veloc', u'point', u'contact', u'semiconductor', u'substrat', u'second', u'roller', u'.', u'19', u'.', u'The', u'apparatu', u'defin', u'cl ...

# %%
# MAKE DF OF STEMMED
stemmed_df = pd.DataFrame(stemmed, columns=['words'])
stemmed_df
# Out:
#              words
# 0               ~~
# 1                1
# 2                .
# 3                A
# 4         scrubber
# 5            scrub
# 6    semiconductor
# 7            wafer
# 8              edg
# 9                ,
# 10         compris
# 11               :
# 12           first
# 13          roller
# 14           clean
# 15             edg
# 16   semiconductor
# 17           wafer
# 18               ,
# 19          second
# 20          roller
# 21           rotat
# 22   semiconductor
# 23           wafer
# 24               ,
# 25           first
# 26          roller
# 27        configur
# 28           rotat
# 29          direct
# ..             ...
# 596          claim
# 597             29
# 598        wherein
# 599           said
# 600          least
# 601            one
# 602         chemic
# 603        compris
# 604             NH
# 605              4
# 606             OH
# 607              .
# 608             31
# 609              .
# 610            The
# 611       apparatu
# 612          defin
# 613          claim
# 614             29
# 615        wherein
# 616           said
# 617          least
# 618            one
# 619         chemic
# 620        compris
# 621        NH4OH/H
# 622              2
# 623              O
# 624              2
# 625              .
#
# [626 rows x 1 columns]

# %%
# COUNT OCCURRENCE OF UNIGRAMS
data = stemmed
count_uni = Counter()
for elem in data:
    count_uni[elem] += 1
countUNI = dict(count_uni)

# %%
# MAKE DF OF UNIGRAMS
countUNI_df = pd.DataFrame.from_dict(countUNI, orient='index')
countUNI_df
#EXPORT TO CSV
countUNI_df.to_csv(path_or_buf='/Users/jillschulze/Desktop/PS2/countUNI_6334229.csv')

# %% [markdown]
# Bigram and Trigram code snippets from "Locally Optimal" blog: http://locallyoptimal.com/blog/2013/01/20/elegant-n-gram-generation-in-python/. Another noteable option, though more complex, is from StackOverflow: http://stackoverflow.com/questions/21844546/forming-bigrams-of-words-in-list-of-sentences-python.

# %%
# BIGRAMS
input_list = stemmed

def find_bigrams(input_list):
  return zip(input_list, input_list[1:])

bigrams = zip(input_list, input_list[1:])
print bigrams
# Out:
# [(u'~~', u'1'), (u'1', u'.'), (u'.', u'A'), (u'A', u'scrubber'), (u'scrubber', u'scrub'), (u'scrub', u'semiconductor'), (u'semiconductor', u'wafer'), (u'wafer', u'edg'), (u'edg', u','), (u',', u'compris'), (u'compris', u':'), (u':', u'first'), (u'first', u'roller'), (u'roller', u'clean'), (u'clean', u'edg'), (u'edg', u'semiconductor'), (u'semiconductor', u'wafer'), (u'wafer', u','), (u',', u'second'), (u'second', u'roller'), (u'roller', u'rotat'), (u'rotat', u'semiconductor'), (u'semiconductor', u'wafer'), (u'wafer', u','), (u',', u'first'), (u'first', u'roller'), (u'roller', u'configur'), (u'configur', u'rotat'), (u'rotat', u'direct'), (u'direct', u'first'), (u'first', u'speed'), (u'speed', u'second'), (u'second', u'roller'), (u'roller', u'configur'), (u'configur', u'rotat'), (u'rotat', u'direct'), (u'direct', u'second'), (u'second', u'speed'), (u'speed', u'facilit'), (u'facilit', u'edg'), (u'edg', u'clean'), (u'clean', u'semiconductor'), (u'semiconductor', u'wafer'), (u'wafer', u'first'), (u'first', u'roller'), (u'roller', u','), (u',', u'edg'), (u'edg', u'semiconductor'), (u'semiconductor', u'wafer'), (u'wafer', u'clean'), (u'clean', u'due'), (u'due', u'friction'), (u'friction', u'differ'), (u'differ', u'tangenti'), (u'tangenti', u'veloc'), (u'veloc', u'point'), (u'point', u'contact'), (u'contact', u'semiconductor'), (u'semiconductor', u'wafer'), (u'wafer', u'first'), (u'first', u'roller'), (u'roller', u'.'), (u'.', u'2'), (u'2', u'.'), (u'.', u'The'), (u'The', u'scrubber'), (u'scrubber', u'defin'), (u'defin', u'claim'), (u'claim', u'1'), (u'1', u'wherein'), (u'wherein', u'mechan'), (u'mechan', u'edg'), (u'edg', u'clean'), (u'clean', u'particl'), (u'particl', u'bevel'), (u'bevel', u'area'), (u'area', u'semiconductor'), (u'semiconductor', u'wafer'), (u'wafer', u'.'), (u'.', u'3'), (u'3', u'.'), (u'.', u'The'), (u'The', u'scrubber'), (u'scrubber', u'defin'), (u'defin', u'claim'), (u'claim', u'1'), (u'1', u'wherein'), (u'wherein', u'edg'), (u'edg', u'semiconductor'), (u'semiconductor', u'wafer'), (u'wafer', u'clean'), (u'clean', u'due'), (u'due', u'friction'), (u'friction', u'edg'), (u'edg', u'abras'), (u'abras', u'materi'), (u'materi', u'.'), (u'.', u'4'), (u'4', u'.'), (u'.', u'The'), (u'The', u'scrubber'), (u'scrubber', u'defin'), (u'defin', u'claim'), (u'claim', u'1'), (u'1', u'wherein'), (u'wherein', u'first'), (u'first', u'roller'), (u'roller', u'compris'), (u'compris', u'abras'), (u'abras', u'materi'), (u'materi', u'.'), (u'.', u'5'), (u'5', u'.'), (u'.', u'The'), (u'The', u'scrubber'), (u'scrubber', u'defin'), (u'defin', u'claim'), (u'claim', u'4'), (u'4', u'wherein'), (u'wherein', u'second'), (u'second', u'speed'), (u'speed', u'faster'), (u'faster', u'first'), (u'first', u'speed'), (u'speed', u'.'), (u'.', u'6'), (u'6', u'.'), (u'.', u'The'), (u'The', u'scrubber'), (u'scrubber', u'defin'), (u'defin', u'claim'), (u'claim', u'5'), (u'5', u'wherein'), (u'wherein', u'second'), (u'second', u'speed'), (u'speed', u'approxim'), (u'approxim', u'1.5'), (u'1.5', u'time'), (u'time', u'first'), (u'first', u'speed'), (u'speed', u'.'), (u'.', u'7'), (u'7', u'.'), (u'.', u'The'), (u'The', u'scrubber'), (u'scrubber', u'defin'), (u'defin', u'claim'), (u'claim', u'4'), (u'4', u'wherein'), (u'wherein', u'clean'), (u'clean', u'mechan'), (u'mechan', u'compris'), (u'compris', u'water'), (u'water', u'jet'), (u'jet', u'propel'), (u'propel', u'water'), (u'water', u'area'), (u'area', u'contact'), (u'contact', u'semiconductor'), (u'semiconductor', u'wafer'), (u'wafer', u'first'), (u'first', u'roller'), (u'roller', u'.'), (u'.', u'8'), (u'8', u'.'), (u'.', u'The'), (u'The', u'scrubber'), (u'scrubber', u'defin'), (u'defin', u'claim'), (u'claim', u'1'), (u'1', u'wherein'), (u'wherein', u'second'), (u'second', u'roller'), (u'roller', u'compris'), (u'compris', u'abras'), (u'abras', u'materi'), (u'materi', u'.'), (u'.', u'9'), (u'9', u'.'), (u'.', u'The'), (u'The', u'scrubber'), (u'scrubber', u'defin'), (u'defin', u'claim'), (u'claim', u'8'), (u'8', u ...

# %%
# COUNT OCCURRENCE OF BIGRAMS
data = bigrams
count_bi = Counter()
for elem in data:
    count_bi[elem] += 1
dict(count_bi)
# Out:
# {(u'(', u'PVA'): 3,
#  (u')', u'.'): 3,
#  (u',', u'compris'): 2,
#  (u',', u'edg'): 1,
#  (u',', u'first'): 2,
#  (u',', u'said'): 1,
#  (u',', u'second'): 2,
#  (u'.', u'10'): 1,
#  (u'.', u'11'): 1,
#  (u'.', u'12'): 1,
#  (u'.', u'13'): 1,
#  (u'.', u'14'): 1,
#  (u'.', u'15'): 1,
#  (u'.', u'16'): 1,
#  (u'.', u'17'): 1,
#  (u'.', u'18'): 1,
#  (u'.', u'19'): 1,
#  (u'.', u'2'): 1,
#  (u'.', u'20'): 1,
#  (u'.', u'21'): 1,
#  (u'.', u'22'): 1,
#  (u'.', u'23'): 1,
#  (u'.', u'24'): 1,
#  (u'.', u'25'): 1,
#  (u'.', u'26'): 1,
#  (u'.', u'27'): 1,
#  (u'.', u'28'): 1,
#  (u'.', u'29'): 1,
#  (u'.', u'3'): 1,
#  (u'.', u'30'): 1,
#  (u'.', u'31'): 1,
#  (u'.', u'4'): 1,
#  (u'.', u'5'): 1,
#  (u'.', u'6'): 1,
#  (u'.', u'7'): 1,
#  (u'.', u'8'): 1,
#  (u'.', u'9'): 1,
#  (u'.', u'A'): 3,
#  (u'.', u'The'): 28,
#  (u'1', u'.'): 1,
#  (u'1', u'wherein'): 4,
#  (u'1.5', u'time'): 2,
#  (u'10', u'.'): 1,
#  (u'11', u'.'): 1,
#  (u'12', u'.'): 1,
#  (u'13', u'.'): 1,
#  (u'13', u'wherein'): 4,
#  (u'14', u'.'): 1,
#  (u'15', u'.'): 1,
#  (u'16', u'.'): 1,
#  (u'17', u'.'): 1,
#  (u'18', u'.'): 1,
#  (u'18', u'compris'): 2,
#  (u'18', u'wherein'): 5,
#  (u'19', u'.'): 1,
#  (u'2', u'.'): 2,
#  (u'2', u'O'): 1,
#  (u'20', u'.'): 1,
#  (u'20', u'wherein'): 4,
#  (u'21', u'.'): 1,
#  (u'22', u'.'): 1,
#  (u'23', u'.'): 1,
#  (u'24', u'.'): 1,
#  (u'25', u'.'): 1,
#  (u'26', u'.'): 1,
#  (u'27', u'.'): 1,
#  (u'28', u'.'): 1,
#  (u'29', u'.'): 1,
#  (u'29', u'wherein'): 2,
#  (u'3', u'.'): 1,
#  (u'30', u'.'): 1,
#  (u'31', u'.'): 1,
#  (u'4', u'.'): 1,
#  (u'4', u'OH'): 1,
#  (u'4', u'wherein'): 2,
#  (u'5', u'.'): 1,
#  (u'5', u'wherein'): 1,
#  (u'6', u'.'): 1,
#  (u'7', u'.'): 1,
#  (u'8', u'.'): 1,
#  (u'8', u'wherein'): 4,
#  (u'9', u'.'): 1,
#  (u':', u'first'): 3,
#  (u';', u'second'): 2,
#  (u'A', u'scrub'): 1,
#  (u'A', u'scrubber'): 2,
#  (u'NH', u'4'): 1,
#  (u'NH4OH/H', u'2'): 1,
#  (u'O', u'2'): 1,
#  (u'OH', u'.'): 1,
#  (u'PVA', u')'): 3,
#  (u'The', u'apparatu'): 13,
#  (u'The', u'scrubber'): 15,
#  (u'abras', u'materi'): 17,
#  (u'alcohol', u'('): 3,
#  (u'apparatu', u'clean'): 1,
#  (u'apparatu', u'compris'): 1,
#  (u'apparatu', u'defin'): 13,
#  (u'approxim', u'1.5'): 2,
#  (u'area', u','): 1,
#  (u'area', u'contact'): 1,
#  (u'area', u'due'): 1,
#  (u'area', u'semiconductor'): 2,
#  (u'bevel', u'area'): 4,
#  (u'chemic', u'compris'): 2,
#  (u'chemic', u'point'): 1,
#  (u'claim', u'1'): 4,
#  (u'claim', u'13'): 4,
#  (u'claim', u'18'): 7,
#  (u'claim', u'20'): 4,
#  (u'claim', u'29'): 2,
#  (u'claim', u'4'): 2,
#  (u'claim', u'5'): 1,
#  (u'claim', u'8'): 4,
#  (u'clean', u'due'): 3,
#  (u'clean', u'edg'): 1,
#  (u'clean', u'mechan'): 1,
#  (u'clean', u'particl'): 2,
#  (u'clean', u'said'): 1,
#  (u'clean', u'semiconductor'): 4,
#  (u'clear', u'edg'): 1,
#  (u'compris', u':'): 3,
#  (u'compris', u'NH'): 1,
#  (u'compris', u'NH4OH/H'): 1,
#  (u'compris', u'abras'): 4,
#  (u'compris', u'jet'): 1,
#  (u'compris', u'nylon'): 3,
#  (u'compris', u'pad'): 2,
#  (u'compris', u'poli'): 3,
#  (u'compris', u'polyurethan'): 3,
#  (u'compris', u'water'): 2,
#  (u'configur', u'rotat'): 4,
#  (u'contact', u'edg'): 1,
#  (u'contact', u'semiconductor'): 3,
#  (u'contact', u'side'): 2,
#  (u'defin', u'claim'): 28,
#  (u'differ', u'first'): 1,
#  (u'differ', u'tangenti'): 3,
#  (u'direct', u'first'): 3,
#  (u'direct', u'second'): 2,
#  (u'due', u'differ'): 2,
#  (u'due', u'friction'): 2,
#  (u'edg', u','): 3,
#  (u'edg', u'abras'): 2,
#  (u'edg', u'clean'): 6,
#  (u'edg', u'semiconductor'): 5,
#  (u'facilit', u'edg'): 2,
#  (u'faster', u'first'): 1,
#  (u'faster', u'rotat'): 1,
#  (u'first', u'roller'): 14,
#  (u'first', u'speed'): 6,
#  (u'friction', u'differ'): 1,
#  (u'friction', u'edg'): 2,
#  (u'gener', u'friction'): 1,
#  (u'includ', u'least'): 1,
#  (u'jet', u'propel'): 3,
#  (u'least', u'one'): 5,
#  (u'materi', u'.'): 5,
#  (u'materi', u'compris'): 11,
#  (u'materi', u'first'): 1,
#  (u'mechan', u'compris'): 1,
#  (u'mechan', u'edg'): 2,
#  (u'nylon', u'.'): 3,
#  (u'one', u'bevel'): 2,
#  (u'one', u'chemic'): 3,
#  (u'pad', u'.'): 2,
#  (u'particl', u'bevel'): 2,
#  (u'point', u'contact'): 4,
#  (u'poli', u'vinyl'): 3,
#  (u'polyurethan', u'.'): 3,
#  (u'propel', u'least'): 1,
#  (u'propel', u'water'): 2,
#  (u'roller', u','): 1,
#  (u'roller', u'.'): 6,
#  (u'roller', u'approxim'): 1,
#  (u'roller', u'clean'): 2,
#  (u'roller', u'clear'): 1,
#  (u'roller', u'compris'): 4,
#  (u'roller', u'configur'): 4,
#  (u'roller', u'gener'): 1,
#  (u'roller', u'rotat'): 5,
#  (u'roller', u'second'): 1,
#  (u'rotat', u'direct'): 5,
#  (u'rotat', u'semiconductor'): 3,
#  (u'rotat', u'speed'): 4,
#  (u'said', u'apparatu'): 1,
#  (u'said', u'least'): 3,
#  (u'scrub', u'apparatu'): 1,
#  (u'scrub', u'edg'): 1,
#  (u'scrub', u'semiconductor'): 3,
#  (u'scrubber', u'defin'): 15,
#  (u'scrubber', u'scrub'): 2,
#  (u'second', u'roller'): 11,
#  (u'second', u'speed'): 5,
#  (u'semiconductor', u'substrat'): 7,
#  (u'semiconductor', u'wafer'): 14,
#  (u'side', u'scrub'): 2,
#  (u'speed', u'.'): 2,
#  (u'speed', u';'): 1,
#  (u'speed', u'approxim'): 1,
#  (u'speed', u'contact'): 1,
#  (u'speed', u'differ'): 1,
#  (u'speed', u'facilit'): 2,
#  (u'speed', u'faster'): 2,
#  (u'speed', u'first'): 1,
#  (u'speed', u'second'): 4,
#  (u'substrat', u'.'): 2,
#  (u'substrat', u'edg'): 2,
#  (u'substrat', u'first'): 1,
#  (u'substrat', u'includ'): 1,
#  (u'substrat', u'second'): 1,
#  (u'tangenti', u'veloc'): 3,
#  (u'time', u'first'): 1,
#  (u'time', u'rotat'): 1,
#  (u'veloc', u'.'): 1,
#  (u'veloc', u'point'): 2,
#  (u'vinyl', u'alcohol'): 3,
#  (u'wafer', u','): 3,
#  (u'wafer', u'.'): 2,
#  (u'wafer', u';'): 1,
#  (u'wafer', u'clean'): 2,
#  (u'wafer', u'edg'): 2,
#  (u'wafer', u'first'): 4,
#  (u'water', u'area'): 1,
#  (u'water', u'jet'): 2,
#  (u'water', u'point'): 1,
#  (u'wherein', u'abras'): 11,
#  (u'wherein', u'clean'): 1,
#  (u'wherein', u'edg'): 1,
#  (u'wherein', u'first'): 2,
#  (u'wherein', u'mechan'): 2,
#  (u'wherein', u'roller'): 1,
#  (u'wherein', u'rotat'): 1,
#  (u'wherein', u'said'): 2,
#  (u'wherein', u'second'): 4,
#  (u'wherein', u'semiconductor'): 1,
#  (u'~~', u'1'): 1}

# %%
# MAKE DF OF BIGRAMS
countBI_df = pd.DataFrame.from_dict(count_bi, orient='index')
countBI_df

#EXPORT TO CSV
countBI_df.to_csv(path_or_buf='/Users/jillschulze/Desktop/PS2/countBI_6334229.csv')

# %%
# TRIGRAMS
input_list = stemmed

def find_ngrams(input_list, n):
  return zip(*[input_list[i:] for i in range(n)])

trigrams = zip(input_list, input_list[1:], input_list[2:])
print(trigrams)
# Out:
# [(u'~~', u'1', u'.'), (u'1', u'.', u'A'), (u'.', u'A', u'scrubber'), (u'A', u'scrubber', u'scrub'), (u'scrubber', u'scrub', u'semiconductor'), (u'scrub', u'semiconductor', u'wafer'), (u'semiconductor', u'wafer', u'edg'), (u'wafer', u'edg', u','), (u'edg', u',', u'compris'), (u',', u'compris', u':'), (u'compris', u':', u'first'), (u':', u'first', u'roller'), (u'first', u'roller', u'clean'), (u'roller', u'clean', u'edg'), (u'clean', u'edg', u'semiconductor'), (u'edg', u'semiconductor', u'wafer'), (u'semiconductor', u'wafer', u','), (u'wafer', u',', u'second'), (u',', u'second', u'roller'), (u'second', u'roller', u'rotat'), (u'roller', u'rotat', u'semiconductor'), (u'rotat', u'semiconductor', u'wafer'), (u'semiconductor', u'wafer', u','), (u'wafer', u',', u'first'), (u',', u'first', u'roller'), (u'first', u'roller', u'configur'), (u'roller', u'configur', u'rotat'), (u'configur', u'rotat', u'direct'), (u'rotat', u'direct', u'first'), (u'direct', u'first', u'speed'), (u'first', u'speed', u'second'), (u'speed', u'second', u'roller'), (u'second', u'roller', u'configur'), (u'roller', u'configur', u'rotat'), (u'configur', u'rotat', u'direct'), (u'rotat', u'direct', u'second'), (u'direct', u'second', u'speed'), (u'second', u'speed', u'facilit'), (u'speed', u'facilit', u'edg'), (u'facilit', u'edg', u'clean'), (u'edg', u'clean', u'semiconductor'), (u'clean', u'semiconductor', u'wafer'), (u'semiconductor', u'wafer', u'first'), (u'wafer', u'first', u'roller'), (u'first', u'roller', u','), (u'roller', u',', u'edg'), (u',', u'edg', u'semiconductor'), (u'edg', u'semiconductor', u'wafer'), (u'semiconductor', u'wafer', u'clean'), (u'wafer', u'clean', u'due'), (u'clean', u'due', u'friction'), (u'due', u'friction', u'differ'), (u'friction', u'differ', u'tangenti'), (u'differ', u'tangenti', u'veloc'), (u'tangenti', u'veloc', u'point'), (u'veloc', u'point', u'contact'), (u'point', u'contact', u'semiconductor'), (u'contact', u'semiconductor', u'wafer'), (u'semiconductor', u'wafer', u'first'), (u'wafer', u'first', u'roller'), (u'first', u'roller', u'.'), (u'roller', u'.', u'2'), (u'.', u'2', u'.'), (u'2', u'.', u'The'), (u'.', u'The', u'scrubber'), (u'The', u'scrubber', u'defin'), (u'scrubber', u'defin', u'claim'), (u'defin', u'claim', u'1'), (u'claim', u'1', u'wherein'), (u'1', u'wherein', u'mechan'), (u'wherein', u'mechan', u'edg'), (u'mechan', u'edg', u'clean'), (u'edg', u'clean', u'particl'), (u'clean', u'particl', u'bevel'), (u'particl', u'bevel', u'area'), (u'bevel', u'area', u'semiconductor'), (u'area', u'semiconductor', u'wafer'), (u'semiconductor', u'wafer', u'.'), (u'wafer', u'.', u'3'), (u'.', u'3', u'.'), (u'3', u'.', u'The'), (u'.', u'The', u'scrubber'), (u'The', u'scrubber', u'defin'), (u'scrubber', u'defin', u'claim'), (u'defin', u'claim', u'1'), (u'claim', u'1', u'wherein'), (u'1', u'wherein', u'edg'), (u'wherein', u'edg', u'semiconductor'), (u'edg', u'semiconductor', u'wafer'), (u'semiconductor', u'wafer', u'clean'), (u'wafer', u'clean', u'due'), (u'clean', u'due', u'friction'), (u'due', u'friction', u'edg'), (u'friction', u'edg', u'abras'), (u'edg', u'abras', u'materi'), (u'abras', u'materi', u'.'), (u'materi', u'.', u'4'), (u'.', u'4', u'.'), (u'4', u'.', u'The'), (u'.', u'The', u'scrubber'), (u'The', u'scrubber', u'defin'), (u'scrubber', u'defin', u'claim'), (u'defin', u'claim', u'1'), (u'claim', u'1', u'wherein'), (u'1', u'wherein', u'first'), (u'wherein', u'first', u'roller'), (u'first', u'roller', u'compris'), (u'roller', u'compris', u'abras'), (u'compris', u'abras', u'materi'), (u'abras', u'materi', u'.'), (u'materi', u'.', u'5'), (u'.', u'5', u'.'), (u'5', u'.', u'The'), (u'.', u'The', u'scrubber'), (u'The', u'scrubber', u'defin'), (u'scrubber', u'defin', u'claim'), (u'defin', u'claim', u'4'), (u'claim', u'4', u'wherein'), (u'4', u'wherein', u'second'), (u'wherein', u'second', u'speed'), (u'second', u'speed', u'faster'), (u'speed', u'faster', u'first'), (u'faster', u'first', u'speed'), (u'first', u'speed', u'.'), (u'speed', u' ...

# %%
# COUNT OCCURRENCE OF TRIGRAMS
data = trigrams
count_tri = Counter()
for elem in data:
    count_tri[elem] += 1
dict(count_tri)
# Out:
# {(u'(', u'PVA', u')'): 3,
#  (u')', u'.', u'11'): 1,
#  (u')', u'.', u'16'): 1,
#  (u')', u'.', u'23'): 1,
#  (u',', u'compris', u':'): 2,
#  (u',', u'edg', u'semiconductor'): 1,
#  (u',', u'first', u'roller'): 2,
#  (u',', u'said', u'apparatu'): 1,
#  (u',', u'second', u'roller'): 2,
#  (u'.', u'10', u'.'): 1,
#  (u'.', u'11', u'.'): 1,
#  (u'.', u'12', u'.'): 1,
#  (u'.', u'13', u'.'): 1,
#  (u'.', u'14', u'.'): 1,
#  (u'.', u'15', u'.'): 1,
#  (u'.', u'16', u'.'): 1,
#  (u'.', u'17', u'.'): 1,
#  (u'.', u'18', u'.'): 1,
#  (u'.', u'19', u'.'): 1,
#  (u'.', u'2', u'.'): 1,
#  (u'.', u'20', u'.'): 1,
#  (u'.', u'21', u'.'): 1,
#  (u'.', u'22', u'.'): 1,
#  (u'.', u'23', u'.'): 1,
#  (u'.', u'24', u'.'): 1,
#  (u'.', u'25', u'.'): 1,
#  (u'.', u'26', u'.'): 1,
#  (u'.', u'27', u'.'): 1,
#  (u'.', u'28', u'.'): 1,
#  (u'.', u'29', u'.'): 1,
#  (u'.', u'3', u'.'): 1,
#  (u'.', u'30', u'.'): 1,
#  (u'.', u'31', u'.'): 1,
#  (u'.', u'4', u'.'): 1,
#  (u'.', u'5', u'.'): 1,
#  (u'.', u'6', u'.'): 1,
#  (u'.', u'7', u'.'): 1,
#  (u'.', u'8', u'.'): 1,
#  (u'.', u'9', u'.'): 1,
#  (u'.', u'A', u'scrub'): 1,
#  (u'.', u'A', u'scrubber'): 2,
#  (u'.', u'The', u'apparatu'): 13,
#  (u'.', u'The', u'scrubber'): 15,
#  (u'1', u'.', u'A'): 1,
#  (u'1', u'wherein', u'edg'): 1,
#  (u'1', u'wherein', u'first'): 1,
#  (u'1', u'wherein', u'mechan'): 1,
#  (u'1', u'wherein', u'second'): 1,
#  (u'1.5', u'time', u'first'): 1,
#  (u'1.5', u'time', u'rotat'): 1,
#  (u'10', u'.', u'The'): 1,
#  (u'11', u'.', u'The'): 1,
#  (u'12', u'.', u'The'): 1,
#  (u'13', u'.', u'A'): 1,
#  (u'13', u'wherein', u'abras'): 3,
#  (u'13', u'wherein', u'mechan'): 1,
#  (u'14', u'.', u'The'): 1,
#  (u'15', u'.', u'The'): 1,
#  (u'16', u'.', u'The'): 1,
#  (u'17', u'.', u'The'): 1,
#  (u'18', u'.', u'A'): 1,
#  (u'18', u'compris', u'jet'): 1,
#  (u'18', u'compris', u'water'): 1,
#  (u'18', u'wherein', u'first'): 1,
#  (u'18', u'wherein', u'roller'): 1,
#  (u'18', u'wherein', u'rotat'): 1,
#  (u'18', u'wherein', u'second'): 1,
#  (u'18', u'wherein', u'semiconductor'): 1,
#  (u'19', u'.', u'The'): 1,
#  (u'2', u'.', u'The'): 1,
#  (u'2', u'O', u'2'): 1,
#  (u'20', u'.', u'The'): 1,
#  (u'20', u'wherein', u'abras'): 4,
#  (u'21', u'.', u'The'): 1,
#  (u'22', u'.', u'The'): 1,
#  (u'23', u'.', u'The'): 1,
#  (u'24', u'.', u'The'): 1,
#  (u'25', u'.', u'The'): 1,
#  (u'26', u'.', u'The'): 1,
#  (u'27', u'.', u'The'): 1,
#  (u'28', u'.', u'The'): 1,
#  (u'29', u'.', u'The'): 1,
#  (u'29', u'wherein', u'said'): 2,
#  (u'3', u'.', u'The'): 1,
#  (u'30', u'.', u'The'): 1,
#  (u'31', u'.', u'The'): 1,
#  (u'4', u'.', u'The'): 1,
#  (u'4', u'OH', u'.'): 1,
#  (u'4', u'wherein', u'clean'): 1,
#  (u'4', u'wherein', u'second'): 1,
#  (u'5', u'.', u'The'): 1,
#  (u'5', u'wherein', u'second'): 1,
#  (u'6', u'.', u'The'): 1,
#  (u'7', u'.', u'The'): 1,
#  (u'8', u'.', u'The'): 1,
#  (u'8', u'wherein', u'abras'): 4,
#  (u'9', u'.', u'The'): 1,
#  (u':', u'first', u'roller'): 3,
#  (u';', u'second', u'roller'): 2,
#  (u'A', u'scrub', u'apparatu'): 1,
#  (u'A', u'scrubber', u'scrub'): 2,
#  (u'NH', u'4', u'OH'): 1,
#  (u'NH4OH/H', u'2', u'O'): 1,
#  (u'O', u'2', u'.'): 1,
#  (u'OH', u'.', u'31'): 1,
#  (u'PVA', u')', u'.'): 3,
#  (u'The', u'apparatu', u'defin'): 13,
#  (u'The', u'scrubber', u'defin'): 15,
#  (u'abras', u'materi', u'.'): 5,
#  (u'abras', u'materi', u'compris'): 11,
#  (u'abras', u'materi', u'first'): 1,
#  (u'alcohol', u'(', u'PVA'): 3,
#  (u'apparatu', u'clean', u'semiconductor'): 1,
#  (u'apparatu', u'compris', u':'): 1,
#  (u'apparatu', u'defin', u'claim'): 13,
#  (u'approxim', u'1.5', u'time'): 2,
#  (u'area', u',', u'second'): 1,
#  (u'area', u'contact', u'semiconductor'): 1,
#  (u'area', u'due', u'differ'): 1,
#  (u'area', u'semiconductor', u'wafer'): 2,
#  (u'bevel', u'area', u','): 1,
#  (u'bevel', u'area', u'due'): 1,
#  (u'bevel', u'area', u'semiconductor'): 2,
#  (u'chemic', u'compris', u'NH'): 1,
#  (u'chemic', u'compris', u'NH4OH/H'): 1,
#  (u'chemic', u'point', u'contact'): 1,
#  (u'claim', u'1', u'wherein'): 4,
#  (u'claim', u'13', u'wherein'): 4,
#  (u'claim', u'18', u'compris'): 2,
#  (u'claim', u'18', u'wherein'): 5,
#  (u'claim', u'20', u'wherein'): 4,
#  (u'claim', u'29', u'wherein'): 2,
#  (u'claim', u'4', u'wherein'): 2,
#  (u'claim', u'5', u'wherein'): 1,
#  (u'claim', u'8', u'wherein'): 4,
#  (u'clean', u'due', u'differ'): 1,
#  (u'clean', u'due', u'friction'): 2,
#  (u'clean', u'edg', u'semiconductor'): 1,
#  (u'clean', u'mechan', u'compris'): 1,
#  (u'clean', u'particl', u'bevel'): 2,
#  (u'clean', u'said', u'least'): 1,
#  (u'clean', u'semiconductor', u'substrat'): 2,
#  (u'clean', u'semiconductor', u'wafer'): 2,
#  (u'clear', u'edg', u'semiconductor'): 1,
#  (u'compris', u':', u'first'): 3,
#  (u'compris', u'NH', u'4'): 1,
#  (u'compris', u'NH4OH/H', u'2'): 1,
#  (u'compris', u'abras', u'materi'): 4,
#  (u'compris', u'jet', u'propel'): 1,
#  (u'compris', u'nylon', u'.'): 3,
#  (u'compris', u'pad', u'.'): 2,
#  (u'compris', u'poli', u'vinyl'): 3,
#  (u'compris', u'polyurethan', u'.'): 3,
#  (u'compris', u'water', u'jet'): 2,
#  (u'configur', u'rotat', u'direct'): 4,
#  (u'contact', u'edg', u'semiconductor'): 1,
#  (u'contact', u'semiconductor', u'substrat'): 1,
#  (u'contact', u'semiconductor', u'wafer'): 2,
#  (u'contact', u'side', u'scrub'): 2,
#  (u'defin', u'claim', u'1'): 4,
#  (u'defin', u'claim', u'13'): 4,
#  (u'defin', u'claim', u'18'): 7,
#  (u'defin', u'claim', u'20'): 4,
#  (u'defin', u'claim', u'29'): 2,
#  (u'defin', u'claim', u'4'): 2,
#  (u'defin', u'claim', u'5'): 1,
#  (u'defin', u'claim', u'8'): 4,
#  (u'differ', u'first', u'speed'): 1,
#  (u'differ', u'tangenti', u'veloc'): 3,
#  (u'direct', u'first', u'roller'): 1,
#  (u'direct', u'first', u'speed'): 2,
#  (u'direct', u'second', u'speed'): 2,
#  (u'due', u'differ', u'tangenti'): 2,
#  (u'due', u'friction', u'differ'): 1,
#  (u'due', u'friction', u'edg'): 1,
#  (u'edg', u',', u'compris'): 2,
#  (u'edg', u',', u'said'): 1,
#  (u'edg', u'abras', u'materi'): 2,
#  (u'edg', u'clean', u'due'): 1,
#  (u'edg', u'clean', u'particl'): 2,
#  (u'edg', u'clean', u'semiconductor'): 3,
#  (u'edg', u'semiconductor', u'substrat'): 1,
#  (u'edg', u'semiconductor', u'wafer'): 4,
#  (u'facilit', u'edg', u'clean'): 2,
#  (u'faster', u'first', u'speed'): 1,
#  (u'faster', u'rotat', u'speed'): 1,
#  (u'first', u'roller', u','): 1,
#  (u'first', u'roller', u'.'): 3,
#  (u'first', u'roller', u'approxim'): 1,
#  (u'first', u'roller', u'clean'): 1,
#  (u'first', u'roller', u'clear'): 1,
#  (u'first', u'roller', u'compris'): 1,
#  (u'first', u'roller', u'configur'): 2,
#  (u'first', u'roller', u'gener'): 1,
#  (u'first', u'roller', u'rotat'): 2,
#  (u'first', u'roller', u'second'): 1,
#  (u'first', u'speed', u'.'): 2,
#  (u'first', u'speed', u';'): 1,
#  (u'first', u'speed', u'contact'): 1,
#  (u'first', u'speed', u'second'): 2,
#  (u'friction', u'differ', u'tangenti'): 1,
#  (u'friction', u'edg', u'abras'): 2,
#  (u'gener', u'friction', u'edg'): 1,
#  (u'includ', u'least', u'one'): 1,
#  (u'jet', u'propel', u'least'): 1,
#  (u'jet', u'propel', u'water'): 2,
#  (u'least', u'one', u'bevel'): 2,
#  (u'least', u'one', u'chemic'): 3,
#  (u'materi', u'.', u'21'): 1,
#  (u'materi', u'.', u'26'): 1,
#  (u'materi', u'.', u'4'): 1,
#  (u'materi', u'.', u'5'): 1,
#  (u'materi', u'.', u'9'): 1,
#  (u'materi', u'compris', u'nylon'): 3,
#  (u'materi', u'compris', u'pad'): 2,
#  (u'materi', u'compris', u'poli'): 3,
#  (u'materi', u'compris', u'polyurethan'): 3,
#  (u'materi', u'first', u'roller'): 1,
#  (u'mechan', u'compris', u'water'): 1,
#  (u'mechan', u'edg', u'clean'): 2,
#  (u'nylon', u'.', u'12'): 1,
#  (u'nylon', u'.', u'17'): 1,
#  (u'nylon', u'.', u'24'): 1,
#  (u'one', u'bevel', u'area'): 2,
#  (u'one', u'chemic', u'compris'): 2,
#  (u'one', u'chemic', u'point'): 1,
#  (u'pad', u'.', u'10'): 1,
#  (u'pad', u'.', u'22'): 1,
#  (u'particl', u'bevel', u'area'): 2,
#  (u'point', u'contact', u'semiconductor'): 2,
#  (u'point', u'contact', u'side'): 2,
#  (u'poli', u'vinyl', u'alcohol'): 3,
#  (u'polyurethan', u'.', u'13'): 1,
#  (u'polyurethan', u'.', u'18'): 1,
#  (u'polyurethan', u'.', u'25'): 1,
#  (u'propel', u'least', u'one'): 1,
#  (u'propel', u'water', u'area'): 1,
#  (u'propel', u'water', u'point'): 1,
#  (u'roller', u',', u'edg'): 1,
#  (u'roller', u'.', u'14'): 1,
#  (u'roller', u'.', u'19'): 1,
#  (u'roller', u'.', u'2'): 1,
#  (u'roller', u'.', u'27'): 1,
#  (u'roller', u'.', u'28'): 1,
#  (u'roller', u'.', u'8'): 1,
#  (u'roller', u'approxim', u'1.5'): 1,
#  (u'roller', u'clean', u'edg'): 1,
#  (u'roller', u'clean', u'said'): 1,
#  (u'roller', u'clear', u'edg'): 1,
#  (u'roller', u'compris', u'abras'): 4,
#  (u'roller', u'configur', u'rotat'): 4,
#  (u'roller', u'gener', u'friction'): 1,
#  (u'roller', u'rotat', u'direct'): 1,
#  (u'roller', u'rotat', u'semiconductor'): 3,
#  (u'roller', u'rotat', u'speed'): 1,
#  (u'roller', u'second', u'speed'): 1,
#  (u'rotat', u'direct', u'first'): 3,
#  (u'rotat', u'direct', u'second'): 2,
#  (u'rotat', u'semiconductor', u'substrat'): 1,
#  (u'rotat', u'semiconductor', u'wafer'): 2,
#  (u'rotat', u'speed', u'faster'): 1,
#  (u'rotat', u'speed', u'first'): 1,
#  (u'rotat', u'speed', u'second'): 2,
#  (u'said', u'apparatu', u'compris'): 1,
#  (u'said', u'least', u'one'): 3,
#  (u'scrub', u'apparatu', u'clean'): 1,
#  (u'scrub', u'edg', u'clean'): 1,
#  (u'scrub', u'semiconductor', u'substrat'): 1,
#  (u'scrub', u'semiconductor', u'wafer'): 2,
#  (u'scrubber', u'defin', u'claim'): 15,
#  (u'scrubber', u'scrub', u'semiconductor'): 2,
#  (u'second', u'roller', u'.'): 3,
#  (u'second', u'roller', u'clean'): 1,
#  (u'second', u'roller', u'compris'): 2,
#  (u'second', u'roller', u'configur'): 2,
#  (u'second', u'roller', u'rotat'): 3,
#  (u'second', u'speed', u'approxim'): 1,
#  (u'second', u'speed', u'differ'): 1,
#  (u'second', u'speed', u'facilit'): 2,
#  (u'second', u'speed', u'faster'): 1,
#  (u'semiconductor', u'substrat', u'.'): 2,
#  (u'semiconductor', u'substrat', u'edg'): 2,
#  (u'semiconductor', u'substrat', u'first'): 1,
#  (u'semiconductor', u'substrat', u'includ'): 1,
#  (u'semiconductor', u'substrat', u'second'): 1,
#  (u'semiconductor', u'wafer', u','): 3,
#  (u'semiconductor', u'wafer', u'.'): 2,
#  (u'semiconductor', u'wafer', u';'): 1,
#  (u'semiconductor', u'wafer', u'clean'): 2,
#  (u'semiconductor', u'wafer', u'edg'): 2,
#  (u'semiconductor', u'wafer', u'first'): 4,
#  (u'side', u'scrub', u'edg'): 1,
#  (u'side', u'scrub', u'semiconductor'): 1,
#  (u'speed', u'.', u'6'): 1,
#  (u'speed', u'.', u'7'): 1,
#  (u'speed', u';', u'second'): 1,
#  (u'speed', u'approxim', u'1.5'): 1,
#  (u'speed', u'contact', u'edg'): 1,
#  (u'speed', u'differ', u'first'): 1,
#  (u'speed', u'facilit', u'edg'): 2,
#  (u'speed', u'faster', u'first'): 1,
#  (u'speed', u'faster', u'rotat'): 1,
#  (u'speed', u'first', u'roller'): 1,
#  (u'speed', u'second', u'roller'): 4,
#  (u'substrat', u'.', u'29'): 1,
#  (u'substrat', u'.', u'30'): 1,
#  (u'substrat', u'edg', u','): 1,
#  (u'substrat', u'edg', u'clean'): 1,
#  (u'substrat', u'first', u'speed'): 1,
#  (u'substrat', u'includ', u'least'): 1,
#  (u'substrat', u'second', u'roller'): 1,
#  (u'tangenti', u'veloc', u'.'): 1,
#  (u'tangenti', u'veloc', u'point'): 2,
#  (u'time', u'first', u'speed'): 1,
#  (u'time', u'rotat', u'speed'): 1,
#  (u'veloc', u'.', u'20'): 1,
#  (u'veloc', u'point', u'contact'): 2,
#  (u'vinyl', u'alcohol', u'('): 3,
#  (u'wafer', u',', u'first'): 2,
#  (u'wafer', u',', u'second'): 1,
#  (u'wafer', u'.', u'15'): 1,
#  (u'wafer', u'.', u'3'): 1,
#  (u'wafer', u';', u'second'): 1,
#  (u'wafer', u'clean', u'due'): 2,
#  (u'wafer', u'edg', u','): 2,
#  (u'wafer', u'first', u'roller'): 4,
#  (u'water', u'area', u'contact'): 1,
#  (u'water', u'jet', u'propel'): 2,
#  (u'water', u'point', u'contact'): 1,
#  (u'wherein', u'abras', u'materi'): 11,
#  (u'wherein', u'clean', u'mechan'): 1,
#  (u'wherein', u'edg', u'semiconductor'): 1,
#  (u'wherein', u'first', u'roller'): 2,
#  (u'wherein', u'mechan', u'edg'): 2,
#  (u'wherein', u'roller', u'compris'): 1,
#  (u'wherein', u'rotat', u'speed'): 1,
#  (u'wherein', u'said', u'least'): 2,
#  (u'wherein', u'second', u'roller'): 2,
#  (u'wherein', u'second', u'speed'): 2,
#  (u'wherein', u'semiconductor', u'substrat'): 1,
#  (u'~~', u'1', u'.'): 1}

# %%
# MAKE DF OF BIGRAMS
countTRI_df = pd.DataFrame.from_dict(count_tri, orient='index')
countTRI_df

#EXPORT TO CSV
countTRI_df.to_csv(path_or_buf='/Users/jillschulze/Desktop/PS2/countTRI_6334229.csv')

# %%
# MAKE SUMMARY DF FOR ALL NGRAMS
df = pd.DataFrame()
summary_6334220_df = df.append([countUNI_df, countBI_df, countTRI_df])

#EXPORT TO CSV
summary_6334220_df.to_csv(path_or_buf='/Users/jillschulze/Desktop/PS2/summary_6334229.csv')
