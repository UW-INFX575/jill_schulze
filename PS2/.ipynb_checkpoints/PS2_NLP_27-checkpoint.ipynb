# %%
import csv
import numpy as np
import pandas as pd
from collections import Counter
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.tokenize import WordPunctTokenizer
from nltk.stem.porter import *
from nltk.stem.snowball import SnowballStemmer
from nltk.collocations import BigramCollocationFinder
from nltk.metrics import BigramAssocMeasures

# %%
data = open('6334227.txt', 'r')
data.read()
# Out:
# '~~ 1. A seat of an envelope type, comprising: an upper wall;  a bottom wall;  a side wall; and  incompressible filling pieces occupying a space defined by the bottom, side, and upper walls; and wherein  the bottom wall and the side wall are impermeable and are made of a rigid or semirigid material and at least a portion of the upper wall is made of an elastic and permeable material.  2. The seat as set forth in  claim 1 , wherein the incompressible filling pieces comprise polystyrene balls. 3. The seat as set forth in  claim 1 , wherein the side wall includes an inward rim made of a same material as the side wall, the inward rim being located where the side wall meets the upper wall. 4. The seat as set forth in  claim 1 , wherein the bottom wall is a sheet of inextensible material. 5. The seat as set forth in  claim 1 , wherein the side wall is a sheet of inextensible material. 6. The seat as set forth in  claim 1 , wherein the bottom, side, and upper walls are joined together and form an envelope containing the incompressible filling pieces. 7. The seat as set forth in  claim 6 , wherein the bottom, side, and upper walls are joined together by a sewing process. 8. A seat comprising: at least one envelope including an upper wall, a bottom wall, a side wall, and incompressible filling pieces occupying a space defined by the bottom, side, and upper walls, wherein the bottom wall and the side wall are impermeable, and are made of rigid or semirigid material, and at least a portion of the upper wall is made of an elastic and permeable material; and  at least one belt removably attached to the side wall.  9. The seat as set forth in  claim 8 , wherein the belt comprises: a rigid panel.  10. The seat as set forth in  claim 8 , wherein the belt comprises: a ring of homogenous material.  11. The seat as set forth in  claim 10 , wherein the homogenous material is selected from the group consisting of a rubber and a synthetic foam. 12. The seat as set forth in  claim 8 , wherein the belt comprises: an inflatable ring.'

# %%
#TAKE OUT STOP WORDS
stopset = set(stopwords.words('english'))

with open('6334227.txt', 'r') as text_file:
    text = text_file.read()
    tokens = nltk.word_tokenize(str(text))
    tokens = [w for w in tokens if not w in stopset]
    print tokens
# Out:
# ['~~', '1', '.', 'A', 'seat', 'envelope', 'type', ',', 'comprising', ':', 'upper', 'wall', ';', 'bottom', 'wall', ';', 'side', 'wall', ';', 'incompressible', 'filling', 'pieces', 'occupying', 'space', 'defined', 'bottom', ',', 'side', ',', 'upper', 'walls', ';', 'wherein', 'bottom', 'wall', 'side', 'wall', 'impermeable', 'made', 'rigid', 'semirigid', 'material', 'least', 'portion', 'upper', 'wall', 'made', 'elastic', 'permeable', 'material', '.', '2', '.', 'The', 'seat', 'set', 'forth', 'claim', '1', ',', 'wherein', 'incompressible', 'filling', 'pieces', 'comprise', 'polystyrene', 'balls', '.', '3', '.', 'The', 'seat', 'set', 'forth', 'claim', '1', ',', 'wherein', 'side', 'wall', 'includes', 'inward', 'rim', 'made', 'material', 'side', 'wall', ',', 'inward', 'rim', 'located', 'side', 'wall', 'meets', 'upper', 'wall', '.', '4', '.', 'The', 'seat', 'set', 'forth', 'claim', '1', ',', 'wherein', 'bottom', 'wall', 'sheet', 'inextensible', 'material', '.', '5', '.', 'The', 'seat', 'set', 'forth', 'claim', '1', ',', 'wherein', 'side', 'wall', 'sheet', 'inextensible', 'material', '.', '6', '.', 'The', 'seat', 'set', 'forth', 'claim', '1', ',', 'wherein', 'bottom', ',', 'side', ',', 'upper', 'walls', 'joined', 'together', 'form', 'envelope', 'containing', 'incompressible', 'filling', 'pieces', '.', '7', '.', 'The', 'seat', 'set', 'forth', 'claim', '6', ',', 'wherein', 'bottom', ',', 'side', ',', 'upper', 'walls', 'joined', 'together', 'sewing', 'process', '.', '8', '.', 'A', 'seat', 'comprising', ':', 'least', 'one', 'envelope', 'including', 'upper', 'wall', ',', 'bottom', 'wall', ',', 'side', 'wall', ',', 'incompressible', 'filling', 'pieces', 'occupying', 'space', 'defined', 'bottom', ',', 'side', ',', 'upper', 'walls', ',', 'wherein', 'bottom', 'wall', 'side', 'wall', 'impermeable', ',', 'made', 'rigid', 'semirigid', 'material', ',', 'least', 'portion', 'upper', 'wall', 'made', 'elastic', 'permeable', 'material', ';', 'least', 'one', 'belt', 'removably', 'attached', 'side', 'wall', '.', '9', '.', 'The', 'seat', 'set', 'forth', 'claim', '8', ',', 'wherein', 'belt', 'comprises', ':', 'rigid', 'panel', '.', '10', '.', 'The', 'seat', 'set', 'forth', 'claim', '8', ',', 'wherein', 'belt', 'comprises', ':', 'ring', 'homogenous', 'material', '.', '11', '.', 'The', 'seat', 'set', 'forth', 'claim', '10', ',', 'wherein', 'homogenous', 'material', 'selected', 'group', 'consisting', 'rubber', 'synthetic', 'foam', '.', '12', '.', 'The', 'seat', 'set', 'forth', 'claim', '8', ',', 'wherein', 'belt', 'comprises', ':', 'inflatable', 'ring', '.']

# %%
#STEM 1 TXT FILE for unigrams
stemmer = PorterStemmer()
stemmed = []
text = tokens
for word in text:
    stemmed.append(stemmer.stem(word))
print stemmed
# Out:
# [u'~~', u'1', u'.', u'A', u'seat', u'envelop', u'type', u',', u'compris', u':', u'upper', u'wall', u';', u'bottom', u'wall', u';', u'side', u'wall', u';', u'incompress', u'fill', u'piec', u'occupi', u'space', u'defin', u'bottom', u',', u'side', u',', u'upper', u'wall', u';', u'wherein', u'bottom', u'wall', u'side', u'wall', u'imperm', u'made', u'rigid', u'semirigid', u'materi', u'least', u'portion', u'upper', u'wall', u'made', u'elast', u'permeabl', u'materi', u'.', u'2', u'.', u'The', u'seat', u'set', u'forth', u'claim', u'1', u',', u'wherein', u'incompress', u'fill', u'piec', u'compris', u'polystyren', u'ball', u'.', u'3', u'.', u'The', u'seat', u'set', u'forth', u'claim', u'1', u',', u'wherein', u'side', u'wall', u'includ', u'inward', u'rim', u'made', u'materi', u'side', u'wall', u',', u'inward', u'rim', u'locat', u'side', u'wall', u'meet', u'upper', u'wall', u'.', u'4', u'.', u'The', u'seat', u'set', u'forth', u'claim', u'1', u',', u'wherein', u'bottom', u'wall', u'sheet', u'inextens', u'materi', u'.', u'5', u'.', u'The', u'seat', u'set', u'forth', u'claim', u'1', u',', u'wherein', u'side', u'wall', u'sheet', u'inextens', u'materi', u'.', u'6', u'.', u'The', u'seat', u'set', u'forth', u'claim', u'1', u',', u'wherein', u'bottom', u',', u'side', u',', u'upper', u'wall', u'join', u'togeth', u'form', u'envelop', u'contain', u'incompress', u'fill', u'piec', u'.', u'7', u'.', u'The', u'seat', u'set', u'forth', u'claim', u'6', u',', u'wherein', u'bottom', u',', u'side', u',', u'upper', u'wall', u'join', u'togeth', u'sew', u'process', u'.', u'8', u'.', u'A', u'seat', u'compris', u':', u'least', u'one', u'envelop', u'includ', u'upper', u'wall', u',', u'bottom', u'wall', u',', u'side', u'wall', u',', u'incompress', u'fill', u'piec', u'occupi', u'space', u'defin', u'bottom', u',', u'side', u',', u'upper', u'wall', u',', u'wherein', u'bottom', u'wall', u'side', u'wall', u'imperm', u',', u'made', u'rigid', u'semirigid', u'materi', u',', u'least', u'portion', u'upper', u'wall', u'made', u'elast', u'permeabl', u'materi', u';', u'least', u'one', u'belt', u'remov', u'attach', u'side', u'wall', u'.', u'9', u'.', u'The', u'seat', u'set', u'forth', u'claim', u'8', u',', u'wherein', u'belt', u'compris', u':', u'rigid', u'panel', u'.', u'10', u'.', u'The', u'seat', u'set', u'forth', u'claim', u'8', u',', u'wherein', u'belt', u'compris', u':', u'ring', u'homogen', u'materi', u'.', u'11', u'.', u'The', u'seat', u'set', u'forth', u'claim', u'10', u',', u'wherein', u'homogen', u'materi', u'select', u'group', u'consist', u'rubber', u'synthet', u'foam', u'.', u'12', u'.', u'The', u'seat', u'set', u'forth', u'claim', u'8', u',', u'wherein', u'belt', u'compris', u':', u'inflat', u'ring', u'.']

# %%
# MAKE DF OF STEMMED
stemmed_df = pd.DataFrame(stemmed, columns=['words'])
stemmed_df
# Out:
#           words
# 0            ~~
# 1             1
# 2             .
# 3             A
# 4          seat
# 5       envelop
# 6          type
# 7             ,
# 8       compris
# 9             :
# 10        upper
# 11         wall
# 12            ;
# 13       bottom
# 14         wall
# 15            ;
# 16         side
# 17         wall
# 18            ;
# 19   incompress
# 20         fill
# 21         piec
# 22       occupi
# 23        space
# 24        defin
# 25       bottom
# 26            ,
# 27         side
# 28            ,
# 29        upper
# ..          ...
# 274       forth
# 275       claim
# 276          10
# 277           ,
# 278     wherein
# 279     homogen
# 280      materi
# 281      select
# 282       group
# 283     consist
# 284      rubber
# 285     synthet
# 286        foam
# 287           .
# 288          12
# 289           .
# 290         The
# 291        seat
# 292         set
# 293       forth
# 294       claim
# 295           8
# 296           ,
# 297     wherein
# 298        belt
# 299     compris
# 300           :
# 301      inflat
# 302        ring
# 303           .
#
# [304 rows x 1 columns]

# %%
# COUNT OCCURRENCE OF UNIGRAMS
data = stemmed
count_uni = Counter()
for elem in data:
    count_uni[elem] += 1
countUNI = dict(count_uni)

# %%
# MAKE DF OF UNIGRAMS
countUNI_df = pd.DataFrame.from_dict(countUNI, orient='index')
countUNI_df
#EXPORT TO CSV
countUNI_df.to_csv(path_or_buf='/Users/jillschulze/Desktop/PS2/countUNI_6334227.csv')

# %% [markdown]
# Bigram and Trigram code snippets from "Locally Optimal" blog: http://locallyoptimal.com/blog/2013/01/20/elegant-n-gram-generation-in-python/. Another noteable option, though more complex, is from StackOverflow: http://stackoverflow.com/questions/21844546/forming-bigrams-of-words-in-list-of-sentences-python.

# %%
# BIGRAMS
input_list = stemmed

def find_bigrams(input_list):
  return zip(input_list, input_list[1:])

bigrams = zip(input_list, input_list[1:])
print bigrams
# Out:
# [(u'~~', u'1'), (u'1', u'.'), (u'.', u'A'), (u'A', u'seat'), (u'seat', u'envelop'), (u'envelop', u'type'), (u'type', u','), (u',', u'compris'), (u'compris', u':'), (u':', u'upper'), (u'upper', u'wall'), (u'wall', u';'), (u';', u'bottom'), (u'bottom', u'wall'), (u'wall', u';'), (u';', u'side'), (u'side', u'wall'), (u'wall', u';'), (u';', u'incompress'), (u'incompress', u'fill'), (u'fill', u'piec'), (u'piec', u'occupi'), (u'occupi', u'space'), (u'space', u'defin'), (u'defin', u'bottom'), (u'bottom', u','), (u',', u'side'), (u'side', u','), (u',', u'upper'), (u'upper', u'wall'), (u'wall', u';'), (u';', u'wherein'), (u'wherein', u'bottom'), (u'bottom', u'wall'), (u'wall', u'side'), (u'side', u'wall'), (u'wall', u'imperm'), (u'imperm', u'made'), (u'made', u'rigid'), (u'rigid', u'semirigid'), (u'semirigid', u'materi'), (u'materi', u'least'), (u'least', u'portion'), (u'portion', u'upper'), (u'upper', u'wall'), (u'wall', u'made'), (u'made', u'elast'), (u'elast', u'permeabl'), (u'permeabl', u'materi'), (u'materi', u'.'), (u'.', u'2'), (u'2', u'.'), (u'.', u'The'), (u'The', u'seat'), (u'seat', u'set'), (u'set', u'forth'), (u'forth', u'claim'), (u'claim', u'1'), (u'1', u','), (u',', u'wherein'), (u'wherein', u'incompress'), (u'incompress', u'fill'), (u'fill', u'piec'), (u'piec', u'compris'), (u'compris', u'polystyren'), (u'polystyren', u'ball'), (u'ball', u'.'), (u'.', u'3'), (u'3', u'.'), (u'.', u'The'), (u'The', u'seat'), (u'seat', u'set'), (u'set', u'forth'), (u'forth', u'claim'), (u'claim', u'1'), (u'1', u','), (u',', u'wherein'), (u'wherein', u'side'), (u'side', u'wall'), (u'wall', u'includ'), (u'includ', u'inward'), (u'inward', u'rim'), (u'rim', u'made'), (u'made', u'materi'), (u'materi', u'side'), (u'side', u'wall'), (u'wall', u','), (u',', u'inward'), (u'inward', u'rim'), (u'rim', u'locat'), (u'locat', u'side'), (u'side', u'wall'), (u'wall', u'meet'), (u'meet', u'upper'), (u'upper', u'wall'), (u'wall', u'.'), (u'.', u'4'), (u'4', u'.'), (u'.', u'The'), (u'The', u'seat'), (u'seat', u'set'), (u'set', u'forth'), (u'forth', u'claim'), (u'claim', u'1'), (u'1', u','), (u',', u'wherein'), (u'wherein', u'bottom'), (u'bottom', u'wall'), (u'wall', u'sheet'), (u'sheet', u'inextens'), (u'inextens', u'materi'), (u'materi', u'.'), (u'.', u'5'), (u'5', u'.'), (u'.', u'The'), (u'The', u'seat'), (u'seat', u'set'), (u'set', u'forth'), (u'forth', u'claim'), (u'claim', u'1'), (u'1', u','), (u',', u'wherein'), (u'wherein', u'side'), (u'side', u'wall'), (u'wall', u'sheet'), (u'sheet', u'inextens'), (u'inextens', u'materi'), (u'materi', u'.'), (u'.', u'6'), (u'6', u'.'), (u'.', u'The'), (u'The', u'seat'), (u'seat', u'set'), (u'set', u'forth'), (u'forth', u'claim'), (u'claim', u'1'), (u'1', u','), (u',', u'wherein'), (u'wherein', u'bottom'), (u'bottom', u','), (u',', u'side'), (u'side', u','), (u',', u'upper'), (u'upper', u'wall'), (u'wall', u'join'), (u'join', u'togeth'), (u'togeth', u'form'), (u'form', u'envelop'), (u'envelop', u'contain'), (u'contain', u'incompress'), (u'incompress', u'fill'), (u'fill', u'piec'), (u'piec', u'.'), (u'.', u'7'), (u'7', u'.'), (u'.', u'The'), (u'The', u'seat'), (u'seat', u'set'), (u'set', u'forth'), (u'forth', u'claim'), (u'claim', u'6'), (u'6', u','), (u',', u'wherein'), (u'wherein', u'bottom'), (u'bottom', u','), (u',', u'side'), (u'side', u','), (u',', u'upper'), (u'upper', u'wall'), (u'wall', u'join'), (u'join', u'togeth'), (u'togeth', u'sew'), (u'sew', u'process'), (u'process', u'.'), (u'.', u'8'), (u'8', u'.'), (u'.', u'A'), (u'A', u'seat'), (u'seat', u'compris'), (u'compris', u':'), (u':', u'least'), (u'least', u'one'), (u'one', u'envelop'), (u'envelop', u'includ'), (u'includ', u'upper'), (u'upper', u'wall'), (u'wall', u','), (u',', u'bottom'), (u'bottom', u'wall'), (u'wall', u','), (u',', u'side'), (u'side', u'wall'), (u'wall', u','), (u',', u'incompress'), (u'incompress', u'fill'), (u'fill', u'piec'), (u'piec', u'occupi'), (u'occupi', u'space'), (u'space', u'defin'), (u'defin', u'bottom'), (u'bottom', u','), (u ...

# %%
# COUNT OCCURRENCE OF BIGRAMS
data = bigrams
count_bi = Counter()
for elem in data:
    count_bi[elem] += 1
dict(count_bi)
# Out:
# {(u',', u'bottom'): 1,
#  (u',', u'compris'): 1,
#  (u',', u'incompress'): 1,
#  (u',', u'inward'): 1,
#  (u',', u'least'): 1,
#  (u',', u'made'): 1,
#  (u',', u'side'): 5,
#  (u',', u'upper'): 4,
#  (u',', u'wherein'): 11,
#  (u'.', u'10'): 1,
#  (u'.', u'11'): 1,
#  (u'.', u'12'): 1,
#  (u'.', u'2'): 1,
#  (u'.', u'3'): 1,
#  (u'.', u'4'): 1,
#  (u'.', u'5'): 1,
#  (u'.', u'6'): 1,
#  (u'.', u'7'): 1,
#  (u'.', u'8'): 1,
#  (u'.', u'9'): 1,
#  (u'.', u'A'): 2,
#  (u'.', u'The'): 10,
#  (u'1', u','): 5,
#  (u'1', u'.'): 1,
#  (u'10', u','): 1,
#  (u'10', u'.'): 1,
#  (u'11', u'.'): 1,
#  (u'12', u'.'): 1,
#  (u'2', u'.'): 1,
#  (u'3', u'.'): 1,
#  (u'4', u'.'): 1,
#  (u'5', u'.'): 1,
#  (u'6', u','): 1,
#  (u'6', u'.'): 1,
#  (u'7', u'.'): 1,
#  (u'8', u','): 3,
#  (u'8', u'.'): 1,
#  (u'9', u'.'): 1,
#  (u':', u'inflat'): 1,
#  (u':', u'least'): 1,
#  (u':', u'rigid'): 1,
#  (u':', u'ring'): 1,
#  (u':', u'upper'): 1,
#  (u';', u'bottom'): 1,
#  (u';', u'incompress'): 1,
#  (u';', u'least'): 1,
#  (u';', u'side'): 1,
#  (u';', u'wherein'): 1,
#  (u'A', u'seat'): 2,
#  (u'The', u'seat'): 10,
#  (u'attach', u'side'): 1,
#  (u'ball', u'.'): 1,
#  (u'belt', u'compris'): 3,
#  (u'belt', u'remov'): 1,
#  (u'bottom', u','): 4,
#  (u'bottom', u'wall'): 5,
#  (u'claim', u'1'): 5,
#  (u'claim', u'10'): 1,
#  (u'claim', u'6'): 1,
#  (u'claim', u'8'): 3,
#  (u'compris', u':'): 5,
#  (u'compris', u'polystyren'): 1,
#  (u'consist', u'rubber'): 1,
#  (u'contain', u'incompress'): 1,
#  (u'defin', u'bottom'): 2,
#  (u'elast', u'permeabl'): 2,
#  (u'envelop', u'contain'): 1,
#  (u'envelop', u'includ'): 1,
#  (u'envelop', u'type'): 1,
#  (u'fill', u'piec'): 4,
#  (u'foam', u'.'): 1,
#  (u'form', u'envelop'): 1,
#  (u'forth', u'claim'): 10,
#  (u'group', u'consist'): 1,
#  (u'homogen', u'materi'): 2,
#  (u'imperm', u','): 1,
#  (u'imperm', u'made'): 1,
#  (u'includ', u'inward'): 1,
#  (u'includ', u'upper'): 1,
#  (u'incompress', u'fill'): 4,
#  (u'inextens', u'materi'): 2,
#  (u'inflat', u'ring'): 1,
#  (u'inward', u'rim'): 2,
#  (u'join', u'togeth'): 2,
#  (u'least', u'one'): 2,
#  (u'least', u'portion'): 2,
#  (u'locat', u'side'): 1,
#  (u'made', u'elast'): 2,
#  (u'made', u'materi'): 1,
#  (u'made', u'rigid'): 2,
#  (u'materi', u','): 1,
#  (u'materi', u'.'): 4,
#  (u'materi', u';'): 1,
#  (u'materi', u'least'): 1,
#  (u'materi', u'select'): 1,
#  (u'materi', u'side'): 1,
#  (u'meet', u'upper'): 1,
#  (u'occupi', u'space'): 2,
#  (u'one', u'belt'): 1,
#  (u'one', u'envelop'): 1,
#  (u'panel', u'.'): 1,
#  (u'permeabl', u'materi'): 2,
#  (u'piec', u'.'): 1,
#  (u'piec', u'compris'): 1,
#  (u'piec', u'occupi'): 2,
#  (u'polystyren', u'ball'): 1,
#  (u'portion', u'upper'): 2,
#  (u'process', u'.'): 1,
#  (u'remov', u'attach'): 1,
#  (u'rigid', u'panel'): 1,
#  (u'rigid', u'semirigid'): 2,
#  (u'rim', u'locat'): 1,
#  (u'rim', u'made'): 1,
#  (u'ring', u'.'): 1,
#  (u'ring', u'homogen'): 1,
#  (u'rubber', u'synthet'): 1,
#  (u'seat', u'compris'): 1,
#  (u'seat', u'envelop'): 1,
#  (u'seat', u'set'): 10,
#  (u'select', u'group'): 1,
#  (u'semirigid', u'materi'): 2,
#  (u'set', u'forth'): 10,
#  (u'sew', u'process'): 1,
#  (u'sheet', u'inextens'): 2,
#  (u'side', u','): 4,
#  (u'side', u'wall'): 9,
#  (u'space', u'defin'): 2,
#  (u'synthet', u'foam'): 1,
#  (u'togeth', u'form'): 1,
#  (u'togeth', u'sew'): 1,
#  (u'type', u','): 1,
#  (u'upper', u'wall'): 9,
#  (u'wall', u','): 5,
#  (u'wall', u'.'): 2,
#  (u'wall', u';'): 4,
#  (u'wall', u'imperm'): 2,
#  (u'wall', u'includ'): 1,
#  (u'wall', u'join'): 2,
#  (u'wall', u'made'): 2,
#  (u'wall', u'meet'): 1,
#  (u'wall', u'sheet'): 2,
#  (u'wall', u'side'): 2,
#  (u'wherein', u'belt'): 3,
#  (u'wherein', u'bottom'): 5,
#  (u'wherein', u'homogen'): 1,
#  (u'wherein', u'incompress'): 1,
#  (u'wherein', u'side'): 2,
#  (u'~~', u'1'): 1}

# %%
# MAKE DF OF BIGRAMS
countBI_df = pd.DataFrame.from_dict(count_bi, orient='index')
countBI_df

#EXPORT TO CSV
countBI_df.to_csv(path_or_buf='/Users/jillschulze/Desktop/PS2/countBI_6334227.csv')

# %%
# TRIGRAMS
input_list = stemmed

def find_ngrams(input_list, n):
  return zip(*[input_list[i:] for i in range(n)])

trigrams = zip(input_list, input_list[1:], input_list[2:])
print(trigrams)
# Out:
# [(u'~~', u'1', u'.'), (u'1', u'.', u'A'), (u'.', u'A', u'seat'), (u'A', u'seat', u'envelop'), (u'seat', u'envelop', u'type'), (u'envelop', u'type', u','), (u'type', u',', u'compris'), (u',', u'compris', u':'), (u'compris', u':', u'upper'), (u':', u'upper', u'wall'), (u'upper', u'wall', u';'), (u'wall', u';', u'bottom'), (u';', u'bottom', u'wall'), (u'bottom', u'wall', u';'), (u'wall', u';', u'side'), (u';', u'side', u'wall'), (u'side', u'wall', u';'), (u'wall', u';', u'incompress'), (u';', u'incompress', u'fill'), (u'incompress', u'fill', u'piec'), (u'fill', u'piec', u'occupi'), (u'piec', u'occupi', u'space'), (u'occupi', u'space', u'defin'), (u'space', u'defin', u'bottom'), (u'defin', u'bottom', u','), (u'bottom', u',', u'side'), (u',', u'side', u','), (u'side', u',', u'upper'), (u',', u'upper', u'wall'), (u'upper', u'wall', u';'), (u'wall', u';', u'wherein'), (u';', u'wherein', u'bottom'), (u'wherein', u'bottom', u'wall'), (u'bottom', u'wall', u'side'), (u'wall', u'side', u'wall'), (u'side', u'wall', u'imperm'), (u'wall', u'imperm', u'made'), (u'imperm', u'made', u'rigid'), (u'made', u'rigid', u'semirigid'), (u'rigid', u'semirigid', u'materi'), (u'semirigid', u'materi', u'least'), (u'materi', u'least', u'portion'), (u'least', u'portion', u'upper'), (u'portion', u'upper', u'wall'), (u'upper', u'wall', u'made'), (u'wall', u'made', u'elast'), (u'made', u'elast', u'permeabl'), (u'elast', u'permeabl', u'materi'), (u'permeabl', u'materi', u'.'), (u'materi', u'.', u'2'), (u'.', u'2', u'.'), (u'2', u'.', u'The'), (u'.', u'The', u'seat'), (u'The', u'seat', u'set'), (u'seat', u'set', u'forth'), (u'set', u'forth', u'claim'), (u'forth', u'claim', u'1'), (u'claim', u'1', u','), (u'1', u',', u'wherein'), (u',', u'wherein', u'incompress'), (u'wherein', u'incompress', u'fill'), (u'incompress', u'fill', u'piec'), (u'fill', u'piec', u'compris'), (u'piec', u'compris', u'polystyren'), (u'compris', u'polystyren', u'ball'), (u'polystyren', u'ball', u'.'), (u'ball', u'.', u'3'), (u'.', u'3', u'.'), (u'3', u'.', u'The'), (u'.', u'The', u'seat'), (u'The', u'seat', u'set'), (u'seat', u'set', u'forth'), (u'set', u'forth', u'claim'), (u'forth', u'claim', u'1'), (u'claim', u'1', u','), (u'1', u',', u'wherein'), (u',', u'wherein', u'side'), (u'wherein', u'side', u'wall'), (u'side', u'wall', u'includ'), (u'wall', u'includ', u'inward'), (u'includ', u'inward', u'rim'), (u'inward', u'rim', u'made'), (u'rim', u'made', u'materi'), (u'made', u'materi', u'side'), (u'materi', u'side', u'wall'), (u'side', u'wall', u','), (u'wall', u',', u'inward'), (u',', u'inward', u'rim'), (u'inward', u'rim', u'locat'), (u'rim', u'locat', u'side'), (u'locat', u'side', u'wall'), (u'side', u'wall', u'meet'), (u'wall', u'meet', u'upper'), (u'meet', u'upper', u'wall'), (u'upper', u'wall', u'.'), (u'wall', u'.', u'4'), (u'.', u'4', u'.'), (u'4', u'.', u'The'), (u'.', u'The', u'seat'), (u'The', u'seat', u'set'), (u'seat', u'set', u'forth'), (u'set', u'forth', u'claim'), (u'forth', u'claim', u'1'), (u'claim', u'1', u','), (u'1', u',', u'wherein'), (u',', u'wherein', u'bottom'), (u'wherein', u'bottom', u'wall'), (u'bottom', u'wall', u'sheet'), (u'wall', u'sheet', u'inextens'), (u'sheet', u'inextens', u'materi'), (u'inextens', u'materi', u'.'), (u'materi', u'.', u'5'), (u'.', u'5', u'.'), (u'5', u'.', u'The'), (u'.', u'The', u'seat'), (u'The', u'seat', u'set'), (u'seat', u'set', u'forth'), (u'set', u'forth', u'claim'), (u'forth', u'claim', u'1'), (u'claim', u'1', u','), (u'1', u',', u'wherein'), (u',', u'wherein', u'side'), (u'wherein', u'side', u'wall'), (u'side', u'wall', u'sheet'), (u'wall', u'sheet', u'inextens'), (u'sheet', u'inextens', u'materi'), (u'inextens', u'materi', u'.'), (u'materi', u'.', u'6'), (u'.', u'6', u'.'), (u'6', u'.', u'The'), (u'.', u'The', u'seat'), (u'The', u'seat', u'set'), (u'seat', u'set', u'forth'), (u'set', u'forth', u'claim'), (u'forth', u'claim', u'1'), (u'claim', u'1', u','), (u'1', u',', u'wherein'), (u',', u'wherein', u'bottom'), (u'wherein', u'bottom ...

# %%
# COUNT OCCURRENCE OF TRIGRAMS
data = trigrams
count_tri = Counter()
for elem in data:
    count_tri[elem] += 1
dict(count_tri)
# Out:
# {(u',', u'bottom', u'wall'): 1,
#  (u',', u'compris', u':'): 1,
#  (u',', u'incompress', u'fill'): 1,
#  (u',', u'inward', u'rim'): 1,
#  (u',', u'least', u'portion'): 1,
#  (u',', u'made', u'rigid'): 1,
#  (u',', u'side', u','): 4,
#  (u',', u'side', u'wall'): 1,
#  (u',', u'upper', u'wall'): 4,
#  (u',', u'wherein', u'belt'): 3,
#  (u',', u'wherein', u'bottom'): 4,
#  (u',', u'wherein', u'homogen'): 1,
#  (u',', u'wherein', u'incompress'): 1,
#  (u',', u'wherein', u'side'): 2,
#  (u'.', u'10', u'.'): 1,
#  (u'.', u'11', u'.'): 1,
#  (u'.', u'12', u'.'): 1,
#  (u'.', u'2', u'.'): 1,
#  (u'.', u'3', u'.'): 1,
#  (u'.', u'4', u'.'): 1,
#  (u'.', u'5', u'.'): 1,
#  (u'.', u'6', u'.'): 1,
#  (u'.', u'7', u'.'): 1,
#  (u'.', u'8', u'.'): 1,
#  (u'.', u'9', u'.'): 1,
#  (u'.', u'A', u'seat'): 2,
#  (u'.', u'The', u'seat'): 10,
#  (u'1', u',', u'wherein'): 5,
#  (u'1', u'.', u'A'): 1,
#  (u'10', u',', u'wherein'): 1,
#  (u'10', u'.', u'The'): 1,
#  (u'11', u'.', u'The'): 1,
#  (u'12', u'.', u'The'): 1,
#  (u'2', u'.', u'The'): 1,
#  (u'3', u'.', u'The'): 1,
#  (u'4', u'.', u'The'): 1,
#  (u'5', u'.', u'The'): 1,
#  (u'6', u',', u'wherein'): 1,
#  (u'6', u'.', u'The'): 1,
#  (u'7', u'.', u'The'): 1,
#  (u'8', u',', u'wherein'): 3,
#  (u'8', u'.', u'A'): 1,
#  (u'9', u'.', u'The'): 1,
#  (u':', u'inflat', u'ring'): 1,
#  (u':', u'least', u'one'): 1,
#  (u':', u'rigid', u'panel'): 1,
#  (u':', u'ring', u'homogen'): 1,
#  (u':', u'upper', u'wall'): 1,
#  (u';', u'bottom', u'wall'): 1,
#  (u';', u'incompress', u'fill'): 1,
#  (u';', u'least', u'one'): 1,
#  (u';', u'side', u'wall'): 1,
#  (u';', u'wherein', u'bottom'): 1,
#  (u'A', u'seat', u'compris'): 1,
#  (u'A', u'seat', u'envelop'): 1,
#  (u'The', u'seat', u'set'): 10,
#  (u'attach', u'side', u'wall'): 1,
#  (u'ball', u'.', u'3'): 1,
#  (u'belt', u'compris', u':'): 3,
#  (u'belt', u'remov', u'attach'): 1,
#  (u'bottom', u',', u'side'): 4,
#  (u'bottom', u'wall', u','): 1,
#  (u'bottom', u'wall', u';'): 1,
#  (u'bottom', u'wall', u'sheet'): 1,
#  (u'bottom', u'wall', u'side'): 2,
#  (u'claim', u'1', u','): 5,
#  (u'claim', u'10', u','): 1,
#  (u'claim', u'6', u','): 1,
#  (u'claim', u'8', u','): 3,
#  (u'compris', u':', u'inflat'): 1,
#  (u'compris', u':', u'least'): 1,
#  (u'compris', u':', u'rigid'): 1,
#  (u'compris', u':', u'ring'): 1,
#  (u'compris', u':', u'upper'): 1,
#  (u'compris', u'polystyren', u'ball'): 1,
#  (u'consist', u'rubber', u'synthet'): 1,
#  (u'contain', u'incompress', u'fill'): 1,
#  (u'defin', u'bottom', u','): 2,
#  (u'elast', u'permeabl', u'materi'): 2,
#  (u'envelop', u'contain', u'incompress'): 1,
#  (u'envelop', u'includ', u'upper'): 1,
#  (u'envelop', u'type', u','): 1,
#  (u'fill', u'piec', u'.'): 1,
#  (u'fill', u'piec', u'compris'): 1,
#  (u'fill', u'piec', u'occupi'): 2,
#  (u'foam', u'.', u'12'): 1,
#  (u'form', u'envelop', u'contain'): 1,
#  (u'forth', u'claim', u'1'): 5,
#  (u'forth', u'claim', u'10'): 1,
#  (u'forth', u'claim', u'6'): 1,
#  (u'forth', u'claim', u'8'): 3,
#  (u'group', u'consist', u'rubber'): 1,
#  (u'homogen', u'materi', u'.'): 1,
#  (u'homogen', u'materi', u'select'): 1,
#  (u'imperm', u',', u'made'): 1,
#  (u'imperm', u'made', u'rigid'): 1,
#  (u'includ', u'inward', u'rim'): 1,
#  (u'includ', u'upper', u'wall'): 1,
#  (u'incompress', u'fill', u'piec'): 4,
#  (u'inextens', u'materi', u'.'): 2,
#  (u'inflat', u'ring', u'.'): 1,
#  (u'inward', u'rim', u'locat'): 1,
#  (u'inward', u'rim', u'made'): 1,
#  (u'join', u'togeth', u'form'): 1,
#  (u'join', u'togeth', u'sew'): 1,
#  (u'least', u'one', u'belt'): 1,
#  (u'least', u'one', u'envelop'): 1,
#  (u'least', u'portion', u'upper'): 2,
#  (u'locat', u'side', u'wall'): 1,
#  (u'made', u'elast', u'permeabl'): 2,
#  (u'made', u'materi', u'side'): 1,
#  (u'made', u'rigid', u'semirigid'): 2,
#  (u'materi', u',', u'least'): 1,
#  (u'materi', u'.', u'11'): 1,
#  (u'materi', u'.', u'2'): 1,
#  (u'materi', u'.', u'5'): 1,
#  (u'materi', u'.', u'6'): 1,
#  (u'materi', u';', u'least'): 1,
#  (u'materi', u'least', u'portion'): 1,
#  (u'materi', u'select', u'group'): 1,
#  (u'materi', u'side', u'wall'): 1,
#  (u'meet', u'upper', u'wall'): 1,
#  (u'occupi', u'space', u'defin'): 2,
#  (u'one', u'belt', u'remov'): 1,
#  (u'one', u'envelop', u'includ'): 1,
#  (u'panel', u'.', u'10'): 1,
#  (u'permeabl', u'materi', u'.'): 1,
#  (u'permeabl', u'materi', u';'): 1,
#  (u'piec', u'.', u'7'): 1,
#  (u'piec', u'compris', u'polystyren'): 1,
#  (u'piec', u'occupi', u'space'): 2,
#  (u'polystyren', u'ball', u'.'): 1,
#  (u'portion', u'upper', u'wall'): 2,
#  (u'process', u'.', u'8'): 1,
#  (u'remov', u'attach', u'side'): 1,
#  (u'rigid', u'panel', u'.'): 1,
#  (u'rigid', u'semirigid', u'materi'): 2,
#  (u'rim', u'locat', u'side'): 1,
#  (u'rim', u'made', u'materi'): 1,
#  (u'ring', u'homogen', u'materi'): 1,
#  (u'rubber', u'synthet', u'foam'): 1,
#  (u'seat', u'compris', u':'): 1,
#  (u'seat', u'envelop', u'type'): 1,
#  (u'seat', u'set', u'forth'): 10,
#  (u'select', u'group', u'consist'): 1,
#  (u'semirigid', u'materi', u','): 1,
#  (u'semirigid', u'materi', u'least'): 1,
#  (u'set', u'forth', u'claim'): 10,
#  (u'sew', u'process', u'.'): 1,
#  (u'sheet', u'inextens', u'materi'): 2,
#  (u'side', u',', u'upper'): 4,
#  (u'side', u'wall', u','): 2,
#  (u'side', u'wall', u'.'): 1,
#  (u'side', u'wall', u';'): 1,
#  (u'side', u'wall', u'imperm'): 2,
#  (u'side', u'wall', u'includ'): 1,
#  (u'side', u'wall', u'meet'): 1,
#  (u'side', u'wall', u'sheet'): 1,
#  (u'space', u'defin', u'bottom'): 2,
#  (u'synthet', u'foam', u'.'): 1,
#  (u'togeth', u'form', u'envelop'): 1,
#  (u'togeth', u'sew', u'process'): 1,
#  (u'type', u',', u'compris'): 1,
#  (u'upper', u'wall', u','): 2,
#  (u'upper', u'wall', u'.'): 1,
#  (u'upper', u'wall', u';'): 2,
#  (u'upper', u'wall', u'join'): 2,
#  (u'upper', u'wall', u'made'): 2,
#  (u'wall', u',', u'bottom'): 1,
#  (u'wall', u',', u'incompress'): 1,
#  (u'wall', u',', u'inward'): 1,
#  (u'wall', u',', u'side'): 1,
#  (u'wall', u',', u'wherein'): 1,
#  (u'wall', u'.', u'4'): 1,
#  (u'wall', u'.', u'9'): 1,
#  (u'wall', u';', u'bottom'): 1,
#  (u'wall', u';', u'incompress'): 1,
#  (u'wall', u';', u'side'): 1,
#  (u'wall', u';', u'wherein'): 1,
#  (u'wall', u'imperm', u','): 1,
#  (u'wall', u'imperm', u'made'): 1,
#  (u'wall', u'includ', u'inward'): 1,
#  (u'wall', u'join', u'togeth'): 2,
#  (u'wall', u'made', u'elast'): 2,
#  (u'wall', u'meet', u'upper'): 1,
#  (u'wall', u'sheet', u'inextens'): 2,
#  (u'wall', u'side', u'wall'): 2,
#  (u'wherein', u'belt', u'compris'): 3,
#  (u'wherein', u'bottom', u','): 2,
#  (u'wherein', u'bottom', u'wall'): 3,
#  (u'wherein', u'homogen', u'materi'): 1,
#  (u'wherein', u'incompress', u'fill'): 1,
#  (u'wherein', u'side', u'wall'): 2,
#  (u'~~', u'1', u'.'): 1}

# %%
# MAKE DF OF BIGRAMS
countTRI_df = pd.DataFrame.from_dict(count_tri, orient='index')
countTRI_df

#EXPORT TO CSV
countTRI_df.to_csv(path_or_buf='/Users/jillschulze/Desktop/PS2/countTRI_6334227.csv')

# %%
# MAKE SUMMARY DF FOR ALL NGRAMS
df = pd.DataFrame()
summary_6334220_df = df.append([countUNI_df, countBI_df, countTRI_df])

#EXPORT TO CSV
summary_6334220_df.to_csv(path_or_buf='/Users/jillschulze/Desktop/PS2/summary_6334227.csv')
