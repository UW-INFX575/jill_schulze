# %%
import csv
import numpy as np
import pandas as pd
from collections import Counter
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.tokenize import WordPunctTokenizer
from nltk.stem.porter import *
from nltk.stem.snowball import SnowballStemmer
from nltk.collocations import BigramCollocationFinder
from nltk.metrics import BigramAssocMeasures

# %%
data = open('6334224.txt', 'r')
data.read()
# Out:
# '~~ 1. A sock that comprises, a toe portion that is composed of five sheaths wherein the five sheaths are formed by four dividers inside the sock, said dividers are knitted to both a bottom and top part of the sock at the toe portion, and  a foot body portion that covers the foot area between heel and toes;  a heel portion that covers the heel, and  an ankle portion that covers the ankle.  2. A sock that comprises, a toe portion wherein there is an inner layer of five sheaths, and  a foot body portion that covers the foot area between heel and toes, and  a heel portion that covers the heel, and  an ankle portion that covers the ankle.  3. A sock that comprises, a toe portion that is composed of five sheaths wherein the five sheaths are independently knitted along root lines of the toes, and  a foot body portion that covers the foot area between heel and toes, and  a heel portion that covers the heel, and  an ankle portion that covers the ankle.'

# %%
#TAKE OUT STOP WORDS
stopset = set(stopwords.words('english'))

with open('6334224.txt', 'r') as text_file:
    text = text_file.read()
    tokens = nltk.word_tokenize(str(text))
    tokens = [w for w in tokens if not w in stopset]
    print tokens
# Out:
# ['~~', '1', '.', 'A', 'sock', 'comprises', ',', 'toe', 'portion', 'composed', 'five', 'sheaths', 'wherein', 'five', 'sheaths', 'formed', 'four', 'dividers', 'inside', 'sock', ',', 'said', 'dividers', 'knitted', 'bottom', 'top', 'part', 'sock', 'toe', 'portion', ',', 'foot', 'body', 'portion', 'covers', 'foot', 'area', 'heel', 'toes', ';', 'heel', 'portion', 'covers', 'heel', ',', 'ankle', 'portion', 'covers', 'ankle', '.', '2', '.', 'A', 'sock', 'comprises', ',', 'toe', 'portion', 'wherein', 'inner', 'layer', 'five', 'sheaths', ',', 'foot', 'body', 'portion', 'covers', 'foot', 'area', 'heel', 'toes', ',', 'heel', 'portion', 'covers', 'heel', ',', 'ankle', 'portion', 'covers', 'ankle', '.', '3', '.', 'A', 'sock', 'comprises', ',', 'toe', 'portion', 'composed', 'five', 'sheaths', 'wherein', 'five', 'sheaths', 'independently', 'knitted', 'along', 'root', 'lines', 'toes', ',', 'foot', 'body', 'portion', 'covers', 'foot', 'area', 'heel', 'toes', ',', 'heel', 'portion', 'covers', 'heel', ',', 'ankle', 'portion', 'covers', 'ankle', '.']

# %%
#STEM 1 TXT FILE for unigrams
stemmer = PorterStemmer()
stemmed = []
text = tokens
for word in text:
    stemmed.append(stemmer.stem(word))
print stemmed
# Out:
# [u'~~', u'1', u'.', u'A', u'sock', u'compris', u',', u'toe', u'portion', u'compos', u'five', u'sheath', u'wherein', u'five', u'sheath', u'form', u'four', u'divid', u'insid', u'sock', u',', u'said', u'divid', u'knit', u'bottom', u'top', u'part', u'sock', u'toe', u'portion', u',', u'foot', u'bodi', u'portion', u'cover', u'foot', u'area', u'heel', u'toe', u';', u'heel', u'portion', u'cover', u'heel', u',', u'ankl', u'portion', u'cover', u'ankl', u'.', u'2', u'.', u'A', u'sock', u'compris', u',', u'toe', u'portion', u'wherein', u'inner', u'layer', u'five', u'sheath', u',', u'foot', u'bodi', u'portion', u'cover', u'foot', u'area', u'heel', u'toe', u',', u'heel', u'portion', u'cover', u'heel', u',', u'ankl', u'portion', u'cover', u'ankl', u'.', u'3', u'.', u'A', u'sock', u'compris', u',', u'toe', u'portion', u'compos', u'five', u'sheath', u'wherein', u'five', u'sheath', u'independ', u'knit', u'along', u'root', u'line', u'toe', u',', u'foot', u'bodi', u'portion', u'cover', u'foot', u'area', u'heel', u'toe', u',', u'heel', u'portion', u'cover', u'heel', u',', u'ankl', u'portion', u'cover', u'ankl', u'.']

# %%
# MAKE DF OF STEMMED
stemmed_df = pd.DataFrame(stemmed, columns=['words'])
stemmed_df
# Out:
#         words
# 0          ~~
# 1           1
# 2           .
# 3           A
# 4        sock
# 5     compris
# 6           ,
# 7         toe
# 8     portion
# 9      compos
# 10       five
# 11     sheath
# 12    wherein
# 13       five
# 14     sheath
# 15       form
# 16       four
# 17      divid
# 18      insid
# 19       sock
# 20          ,
# 21       said
# 22      divid
# 23       knit
# 24     bottom
# 25        top
# 26       part
# 27       sock
# 28        toe
# 29    portion
# ..        ...
# 93     sheath
# 94    wherein
# 95       five
# 96     sheath
# 97   independ
# 98       knit
# 99      along
# 100      root
# 101      line
# 102       toe
# 103         ,
# 104      foot
# 105      bodi
# 106   portion
# 107     cover
# 108      foot
# 109      area
# 110      heel
# 111       toe
# 112         ,
# 113      heel
# 114   portion
# 115     cover
# 116      heel
# 117         ,
# 118      ankl
# 119   portion
# 120     cover
# 121      ankl
# 122         .
#
# [123 rows x 1 columns]

# %%
# COUNT OCCURRENCE OF UNIGRAMS
data = stemmed
count_uni = Counter()
for elem in data:
    count_uni[elem] += 1
countUNI = dict(count_uni)

# %%
# MAKE DF OF UNIGRAMS
countUNI_df = pd.DataFrame.from_dict(countUNI, orient='index')
countUNI_df
#EXPORT TO CSV
countUNI_df.to_csv(path_or_buf='/Users/jillschulze/Desktop/PS2/countUNI_6334224.csv')

# %% [markdown]
# Bigram and Trigram code snippets from "Locally Optimal" blog: http://locallyoptimal.com/blog/2013/01/20/elegant-n-gram-generation-in-python/. Another noteable option, though more complex, is from StackOverflow: http://stackoverflow.com/questions/21844546/forming-bigrams-of-words-in-list-of-sentences-python.

# %%
# BIGRAMS
input_list = stemmed

def find_bigrams(input_list):
  return zip(input_list, input_list[1:])

bigrams = zip(input_list, input_list[1:])
print bigrams
# Out:
# [(u'~~', u'1'), (u'1', u'.'), (u'.', u'A'), (u'A', u'sock'), (u'sock', u'compris'), (u'compris', u','), (u',', u'toe'), (u'toe', u'portion'), (u'portion', u'compos'), (u'compos', u'five'), (u'five', u'sheath'), (u'sheath', u'wherein'), (u'wherein', u'five'), (u'five', u'sheath'), (u'sheath', u'form'), (u'form', u'four'), (u'four', u'divid'), (u'divid', u'insid'), (u'insid', u'sock'), (u'sock', u','), (u',', u'said'), (u'said', u'divid'), (u'divid', u'knit'), (u'knit', u'bottom'), (u'bottom', u'top'), (u'top', u'part'), (u'part', u'sock'), (u'sock', u'toe'), (u'toe', u'portion'), (u'portion', u','), (u',', u'foot'), (u'foot', u'bodi'), (u'bodi', u'portion'), (u'portion', u'cover'), (u'cover', u'foot'), (u'foot', u'area'), (u'area', u'heel'), (u'heel', u'toe'), (u'toe', u';'), (u';', u'heel'), (u'heel', u'portion'), (u'portion', u'cover'), (u'cover', u'heel'), (u'heel', u','), (u',', u'ankl'), (u'ankl', u'portion'), (u'portion', u'cover'), (u'cover', u'ankl'), (u'ankl', u'.'), (u'.', u'2'), (u'2', u'.'), (u'.', u'A'), (u'A', u'sock'), (u'sock', u'compris'), (u'compris', u','), (u',', u'toe'), (u'toe', u'portion'), (u'portion', u'wherein'), (u'wherein', u'inner'), (u'inner', u'layer'), (u'layer', u'five'), (u'five', u'sheath'), (u'sheath', u','), (u',', u'foot'), (u'foot', u'bodi'), (u'bodi', u'portion'), (u'portion', u'cover'), (u'cover', u'foot'), (u'foot', u'area'), (u'area', u'heel'), (u'heel', u'toe'), (u'toe', u','), (u',', u'heel'), (u'heel', u'portion'), (u'portion', u'cover'), (u'cover', u'heel'), (u'heel', u','), (u',', u'ankl'), (u'ankl', u'portion'), (u'portion', u'cover'), (u'cover', u'ankl'), (u'ankl', u'.'), (u'.', u'3'), (u'3', u'.'), (u'.', u'A'), (u'A', u'sock'), (u'sock', u'compris'), (u'compris', u','), (u',', u'toe'), (u'toe', u'portion'), (u'portion', u'compos'), (u'compos', u'five'), (u'five', u'sheath'), (u'sheath', u'wherein'), (u'wherein', u'five'), (u'five', u'sheath'), (u'sheath', u'independ'), (u'independ', u'knit'), (u'knit', u'along'), (u'along', u'root'), (u'root', u'line'), (u'line', u'toe'), (u'toe', u','), (u',', u'foot'), (u'foot', u'bodi'), (u'bodi', u'portion'), (u'portion', u'cover'), (u'cover', u'foot'), (u'foot', u'area'), (u'area', u'heel'), (u'heel', u'toe'), (u'toe', u','), (u',', u'heel'), (u'heel', u'portion'), (u'portion', u'cover'), (u'cover', u'heel'), (u'heel', u','), (u',', u'ankl'), (u'ankl', u'portion'), (u'portion', u'cover'), (u'cover', u'ankl'), (u'ankl', u'.')]

# %%
# COUNT OCCURRENCE OF BIGRAMS
data = bigrams
count_bi = Counter()
for elem in data:
    count_bi[elem] += 1
dict(count_bi)
# Out:
# {(u',', u'ankl'): 3,
#  (u',', u'foot'): 3,
#  (u',', u'heel'): 2,
#  (u',', u'said'): 1,
#  (u',', u'toe'): 3,
#  (u'.', u'2'): 1,
#  (u'.', u'3'): 1,
#  (u'.', u'A'): 3,
#  (u'1', u'.'): 1,
#  (u'2', u'.'): 1,
#  (u'3', u'.'): 1,
#  (u';', u'heel'): 1,
#  (u'A', u'sock'): 3,
#  (u'along', u'root'): 1,
#  (u'ankl', u'.'): 3,
#  (u'ankl', u'portion'): 3,
#  (u'area', u'heel'): 3,
#  (u'bodi', u'portion'): 3,
#  (u'bottom', u'top'): 1,
#  (u'compos', u'five'): 2,
#  (u'compris', u','): 3,
#  (u'cover', u'ankl'): 3,
#  (u'cover', u'foot'): 3,
#  (u'cover', u'heel'): 3,
#  (u'divid', u'insid'): 1,
#  (u'divid', u'knit'): 1,
#  (u'five', u'sheath'): 5,
#  (u'foot', u'area'): 3,
#  (u'foot', u'bodi'): 3,
#  (u'form', u'four'): 1,
#  (u'four', u'divid'): 1,
#  (u'heel', u','): 3,
#  (u'heel', u'portion'): 3,
#  (u'heel', u'toe'): 3,
#  (u'independ', u'knit'): 1,
#  (u'inner', u'layer'): 1,
#  (u'insid', u'sock'): 1,
#  (u'knit', u'along'): 1,
#  (u'knit', u'bottom'): 1,
#  (u'layer', u'five'): 1,
#  (u'line', u'toe'): 1,
#  (u'part', u'sock'): 1,
#  (u'portion', u','): 1,
#  (u'portion', u'compos'): 2,
#  (u'portion', u'cover'): 9,
#  (u'portion', u'wherein'): 1,
#  (u'root', u'line'): 1,
#  (u'said', u'divid'): 1,
#  (u'sheath', u','): 1,
#  (u'sheath', u'form'): 1,
#  (u'sheath', u'independ'): 1,
#  (u'sheath', u'wherein'): 2,
#  (u'sock', u','): 1,
#  (u'sock', u'compris'): 3,
#  (u'sock', u'toe'): 1,
#  (u'toe', u','): 3,
#  (u'toe', u';'): 1,
#  (u'toe', u'portion'): 4,
#  (u'top', u'part'): 1,
#  (u'wherein', u'five'): 2,
#  (u'wherein', u'inner'): 1,
#  (u'~~', u'1'): 1}

# %%
# MAKE DF OF BIGRAMS
countBI_df = pd.DataFrame.from_dict(count_bi, orient='index')
countBI_df

#EXPORT TO CSV
countBI_df.to_csv(path_or_buf='/Users/jillschulze/Desktop/PS2/countBI_6334224.csv')

# %%
# TRIGRAMS
input_list = stemmed

def find_ngrams(input_list, n):
  return zip(*[input_list[i:] for i in range(n)])

trigrams = zip(input_list, input_list[1:], input_list[2:])
print(trigrams)
# Out:
# [(u'~~', u'1', u'.'), (u'1', u'.', u'A'), (u'.', u'A', u'sock'), (u'A', u'sock', u'compris'), (u'sock', u'compris', u','), (u'compris', u',', u'toe'), (u',', u'toe', u'portion'), (u'toe', u'portion', u'compos'), (u'portion', u'compos', u'five'), (u'compos', u'five', u'sheath'), (u'five', u'sheath', u'wherein'), (u'sheath', u'wherein', u'five'), (u'wherein', u'five', u'sheath'), (u'five', u'sheath', u'form'), (u'sheath', u'form', u'four'), (u'form', u'four', u'divid'), (u'four', u'divid', u'insid'), (u'divid', u'insid', u'sock'), (u'insid', u'sock', u','), (u'sock', u',', u'said'), (u',', u'said', u'divid'), (u'said', u'divid', u'knit'), (u'divid', u'knit', u'bottom'), (u'knit', u'bottom', u'top'), (u'bottom', u'top', u'part'), (u'top', u'part', u'sock'), (u'part', u'sock', u'toe'), (u'sock', u'toe', u'portion'), (u'toe', u'portion', u','), (u'portion', u',', u'foot'), (u',', u'foot', u'bodi'), (u'foot', u'bodi', u'portion'), (u'bodi', u'portion', u'cover'), (u'portion', u'cover', u'foot'), (u'cover', u'foot', u'area'), (u'foot', u'area', u'heel'), (u'area', u'heel', u'toe'), (u'heel', u'toe', u';'), (u'toe', u';', u'heel'), (u';', u'heel', u'portion'), (u'heel', u'portion', u'cover'), (u'portion', u'cover', u'heel'), (u'cover', u'heel', u','), (u'heel', u',', u'ankl'), (u',', u'ankl', u'portion'), (u'ankl', u'portion', u'cover'), (u'portion', u'cover', u'ankl'), (u'cover', u'ankl', u'.'), (u'ankl', u'.', u'2'), (u'.', u'2', u'.'), (u'2', u'.', u'A'), (u'.', u'A', u'sock'), (u'A', u'sock', u'compris'), (u'sock', u'compris', u','), (u'compris', u',', u'toe'), (u',', u'toe', u'portion'), (u'toe', u'portion', u'wherein'), (u'portion', u'wherein', u'inner'), (u'wherein', u'inner', u'layer'), (u'inner', u'layer', u'five'), (u'layer', u'five', u'sheath'), (u'five', u'sheath', u','), (u'sheath', u',', u'foot'), (u',', u'foot', u'bodi'), (u'foot', u'bodi', u'portion'), (u'bodi', u'portion', u'cover'), (u'portion', u'cover', u'foot'), (u'cover', u'foot', u'area'), (u'foot', u'area', u'heel'), (u'area', u'heel', u'toe'), (u'heel', u'toe', u','), (u'toe', u',', u'heel'), (u',', u'heel', u'portion'), (u'heel', u'portion', u'cover'), (u'portion', u'cover', u'heel'), (u'cover', u'heel', u','), (u'heel', u',', u'ankl'), (u',', u'ankl', u'portion'), (u'ankl', u'portion', u'cover'), (u'portion', u'cover', u'ankl'), (u'cover', u'ankl', u'.'), (u'ankl', u'.', u'3'), (u'.', u'3', u'.'), (u'3', u'.', u'A'), (u'.', u'A', u'sock'), (u'A', u'sock', u'compris'), (u'sock', u'compris', u','), (u'compris', u',', u'toe'), (u',', u'toe', u'portion'), (u'toe', u'portion', u'compos'), (u'portion', u'compos', u'five'), (u'compos', u'five', u'sheath'), (u'five', u'sheath', u'wherein'), (u'sheath', u'wherein', u'five'), (u'wherein', u'five', u'sheath'), (u'five', u'sheath', u'independ'), (u'sheath', u'independ', u'knit'), (u'independ', u'knit', u'along'), (u'knit', u'along', u'root'), (u'along', u'root', u'line'), (u'root', u'line', u'toe'), (u'line', u'toe', u','), (u'toe', u',', u'foot'), (u',', u'foot', u'bodi'), (u'foot', u'bodi', u'portion'), (u'bodi', u'portion', u'cover'), (u'portion', u'cover', u'foot'), (u'cover', u'foot', u'area'), (u'foot', u'area', u'heel'), (u'area', u'heel', u'toe'), (u'heel', u'toe', u','), (u'toe', u',', u'heel'), (u',', u'heel', u'portion'), (u'heel', u'portion', u'cover'), (u'portion', u'cover', u'heel'), (u'cover', u'heel', u','), (u'heel', u',', u'ankl'), (u',', u'ankl', u'portion'), (u'ankl', u'portion', u'cover'), (u'portion', u'cover', u'ankl'), (u'cover', u'ankl', u'.')]

# %%
# COUNT OCCURRENCE OF TRIGRAMS
data = trigrams
count_tri = Counter()
for elem in data:
    count_tri[elem] += 1
dict(count_tri)
# Out:
# {(u',', u'ankl', u'portion'): 3,
#  (u',', u'foot', u'bodi'): 3,
#  (u',', u'heel', u'portion'): 2,
#  (u',', u'said', u'divid'): 1,
#  (u',', u'toe', u'portion'): 3,
#  (u'.', u'2', u'.'): 1,
#  (u'.', u'3', u'.'): 1,
#  (u'.', u'A', u'sock'): 3,
#  (u'1', u'.', u'A'): 1,
#  (u'2', u'.', u'A'): 1,
#  (u'3', u'.', u'A'): 1,
#  (u';', u'heel', u'portion'): 1,
#  (u'A', u'sock', u'compris'): 3,
#  (u'along', u'root', u'line'): 1,
#  (u'ankl', u'.', u'2'): 1,
#  (u'ankl', u'.', u'3'): 1,
#  (u'ankl', u'portion', u'cover'): 3,
#  (u'area', u'heel', u'toe'): 3,
#  (u'bodi', u'portion', u'cover'): 3,
#  (u'bottom', u'top', u'part'): 1,
#  (u'compos', u'five', u'sheath'): 2,
#  (u'compris', u',', u'toe'): 3,
#  (u'cover', u'ankl', u'.'): 3,
#  (u'cover', u'foot', u'area'): 3,
#  (u'cover', u'heel', u','): 3,
#  (u'divid', u'insid', u'sock'): 1,
#  (u'divid', u'knit', u'bottom'): 1,
#  (u'five', u'sheath', u','): 1,
#  (u'five', u'sheath', u'form'): 1,
#  (u'five', u'sheath', u'independ'): 1,
#  (u'five', u'sheath', u'wherein'): 2,
#  (u'foot', u'area', u'heel'): 3,
#  (u'foot', u'bodi', u'portion'): 3,
#  (u'form', u'four', u'divid'): 1,
#  (u'four', u'divid', u'insid'): 1,
#  (u'heel', u',', u'ankl'): 3,
#  (u'heel', u'portion', u'cover'): 3,
#  (u'heel', u'toe', u','): 2,
#  (u'heel', u'toe', u';'): 1,
#  (u'independ', u'knit', u'along'): 1,
#  (u'inner', u'layer', u'five'): 1,
#  (u'insid', u'sock', u','): 1,
#  (u'knit', u'along', u'root'): 1,
#  (u'knit', u'bottom', u'top'): 1,
#  (u'layer', u'five', u'sheath'): 1,
#  (u'line', u'toe', u','): 1,
#  (u'part', u'sock', u'toe'): 1,
#  (u'portion', u',', u'foot'): 1,
#  (u'portion', u'compos', u'five'): 2,
#  (u'portion', u'cover', u'ankl'): 3,
#  (u'portion', u'cover', u'foot'): 3,
#  (u'portion', u'cover', u'heel'): 3,
#  (u'portion', u'wherein', u'inner'): 1,
#  (u'root', u'line', u'toe'): 1,
#  (u'said', u'divid', u'knit'): 1,
#  (u'sheath', u',', u'foot'): 1,
#  (u'sheath', u'form', u'four'): 1,
#  (u'sheath', u'independ', u'knit'): 1,
#  (u'sheath', u'wherein', u'five'): 2,
#  (u'sock', u',', u'said'): 1,
#  (u'sock', u'compris', u','): 3,
#  (u'sock', u'toe', u'portion'): 1,
#  (u'toe', u',', u'foot'): 1,
#  (u'toe', u',', u'heel'): 2,
#  (u'toe', u';', u'heel'): 1,
#  (u'toe', u'portion', u','): 1,
#  (u'toe', u'portion', u'compos'): 2,
#  (u'toe', u'portion', u'wherein'): 1,
#  (u'top', u'part', u'sock'): 1,
#  (u'wherein', u'five', u'sheath'): 2,
#  (u'wherein', u'inner', u'layer'): 1,
#  (u'~~', u'1', u'.'): 1}

# %%
# MAKE DF OF BIGRAMS
countTRI_df = pd.DataFrame.from_dict(count_tri, orient='index')
countTRI_df

#EXPORT TO CSV
countTRI_df.to_csv(path_or_buf='/Users/jillschulze/Desktop/PS2/countTRI_6334224.csv')

# %%
# MAKE SUMMARY DF FOR ALL NGRAMS
df = pd.DataFrame()
summary_6334220_df = df.append([countUNI_df, countBI_df, countTRI_df])

#EXPORT TO CSV
summary_6334220_df.to_csv(path_or_buf='/Users/jillschulze/Desktop/PS2/summary_6334224.csv')
