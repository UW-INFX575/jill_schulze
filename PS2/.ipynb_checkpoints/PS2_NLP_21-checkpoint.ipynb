# %%
import csv
import numpy as np
import pandas as pd
from collections import Counter
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.tokenize import WordPunctTokenizer
from nltk.stem.porter import *
from nltk.stem.snowball import SnowballStemmer
from nltk.collocations import BigramCollocationFinder
from nltk.metrics import BigramAssocMeasures

# %%
data = open('6334221.txt', 'r')
data.read()
# Out:
# '~~ 1. A sleeping bag including: a) a main body for substantially enclosing the trunk of a user,  b) at least two body part portions in communication with, attached or said main body, each of said at least two body part portions being adapted to enclose, partially or fully, at least one body part of the user,  wherein one of said body part portions includes at least one leg portion integrally formed with the main body, and  wherein another of said body part portions includes at least one arm portion releasably attachable to the main body.  2. A sleeping bag as claimed in  claim 1  wherein said at least two body part portions further includes a head portion. 3. A sleeping bag as claimed in  claim 2 , wherein said head portion is releasably attachable to the main body. 4. A sleeping bag as claimed in  claim 1 , wherein there is provided a substantially water resistant or water proof seal between said main body and the releasably attachable body part portion(s), when attached. 5. A sleeping bag as claimed in  claim 4  wherein said substantially water resistant or water proof seal is in the form of or provided by a releasably sealable flap provided on either the main body or the releasably attachable body part portion(s), and in the region of the attachment. 6. A sleeping bag as claimed in  claim 1 , wherein one or more of the releasable attachable body part portion(s) are comprised of a different material(s) to said main body. 7. A sleeping bag as claimed in  claim 1 , wherein there is provided a gusset in the region where the at least two leg portions meet the main body. 8. A sleeping bag as claimed in  claim 1 , wherein the main body is provided with a drawstring. 9. A sleeping bag as claimed in  claim 1 , wherein said at least one leg portion is provided with feet portion(s) to substantially enclose the feet of the user. 10. A sleeping bag as claimed in  claim 9 , wherein said feet portion(s) are provided with a drawstring to enable a user to draw the feet portion(s) around his/her feet or lower leg. 11. A sleeping bag as claimed in  claim 1 , wherein said at least one arm portion is provided with hand portion(s) to substantially enclose the hands of the user. 12. A sleeping bag as claimed in  claim 1 , wherein said feet portion(s) and/or said hand portion(s) are comprised of a substantially water resistant or water proof material. 13. A sleeping bag as claimed in  claim 1 , wherein said feet portion(s) and/or said hand portion(s) are releasable attachable to said at least one leg portion and arm portion respectively. 14. A sleeping bag as claimed in  claim 1  wherein said at least one leg portion is provided with a drawstring to enable a user to draw said at least one leg portion around his/her leg. 15. A sleeping bag as claimed in  claim 14  wherein said drawstring is located towards a lower part of said at least one leg portion whereby the user may draw said at least one leg portion around his/her lower leg. 16. A sleeping bag as claimed in  claim 1  wherein the main entry into the sleeping bag is provided by a zip fastener running substantially the length of the main body. 17. A sleeping bag as claimed in  claim 16  wherein the zip fastener is located substantially along the middle front portion of the main body. 18. A sleeping bag as claimed in  claim 17  wherein the main entry into the sleeping bag is provided with a substantially water resistant or water proof seal.'

# %%
#TAKE OUT STOP WORDS
stopset = set(stopwords.words('english'))

with open('6334221.txt', 'r') as text_file:
    text = text_file.read()
    tokens = nltk.word_tokenize(str(text))
    tokens = [w for w in tokens if not w in stopset]
    print tokens
# Out:
# ['~~', '1', '.', 'A', 'sleeping', 'bag', 'including', ':', ')', 'main', 'body', 'substantially', 'enclosing', 'trunk', 'user', ',', 'b', ')', 'least', 'two', 'body', 'part', 'portions', 'communication', ',', 'attached', 'said', 'main', 'body', ',', 'said', 'least', 'two', 'body', 'part', 'portions', 'adapted', 'enclose', ',', 'partially', 'fully', ',', 'least', 'one', 'body', 'part', 'user', ',', 'wherein', 'one', 'said', 'body', 'part', 'portions', 'includes', 'least', 'one', 'leg', 'portion', 'integrally', 'formed', 'main', 'body', ',', 'wherein', 'another', 'said', 'body', 'part', 'portions', 'includes', 'least', 'one', 'arm', 'portion', 'releasably', 'attachable', 'main', 'body', '.', '2', '.', 'A', 'sleeping', 'bag', 'claimed', 'claim', '1', 'wherein', 'said', 'least', 'two', 'body', 'part', 'portions', 'includes', 'head', 'portion', '.', '3', '.', 'A', 'sleeping', 'bag', 'claimed', 'claim', '2', ',', 'wherein', 'said', 'head', 'portion', 'releasably', 'attachable', 'main', 'body', '.', '4', '.', 'A', 'sleeping', 'bag', 'claimed', 'claim', '1', ',', 'wherein', 'provided', 'substantially', 'water', 'resistant', 'water', 'proof', 'seal', 'said', 'main', 'body', 'releasably', 'attachable', 'body', 'part', 'portion', '(', ')', ',', 'attached', '.', '5', '.', 'A', 'sleeping', 'bag', 'claimed', 'claim', '4', 'wherein', 'said', 'substantially', 'water', 'resistant', 'water', 'proof', 'seal', 'form', 'provided', 'releasably', 'sealable', 'flap', 'provided', 'either', 'main', 'body', 'releasably', 'attachable', 'body', 'part', 'portion', '(', ')', ',', 'region', 'attachment', '.', '6', '.', 'A', 'sleeping', 'bag', 'claimed', 'claim', '1', ',', 'wherein', 'one', 'releasable', 'attachable', 'body', 'part', 'portion', '(', ')', 'comprised', 'different', 'material', '(', ')', 'said', 'main', 'body', '.', '7', '.', 'A', 'sleeping', 'bag', 'claimed', 'claim', '1', ',', 'wherein', 'provided', 'gusset', 'region', 'least', 'two', 'leg', 'portions', 'meet', 'main', 'body', '.', '8', '.', 'A', 'sleeping', 'bag', 'claimed', 'claim', '1', ',', 'wherein', 'main', 'body', 'provided', 'drawstring', '.', '9', '.', 'A', 'sleeping', 'bag', 'claimed', 'claim', '1', ',', 'wherein', 'said', 'least', 'one', 'leg', 'portion', 'provided', 'feet', 'portion', '(', ')', 'substantially', 'enclose', 'feet', 'user', '.', '10', '.', 'A', 'sleeping', 'bag', 'claimed', 'claim', '9', ',', 'wherein', 'said', 'feet', 'portion', '(', ')', 'provided', 'drawstring', 'enable', 'user', 'draw', 'feet', 'portion', '(', ')', 'around', 'his/her', 'feet', 'lower', 'leg', '.', '11', '.', 'A', 'sleeping', 'bag', 'claimed', 'claim', '1', ',', 'wherein', 'said', 'least', 'one', 'arm', 'portion', 'provided', 'hand', 'portion', '(', ')', 'substantially', 'enclose', 'hands', 'user', '.', '12', '.', 'A', 'sleeping', 'bag', 'claimed', 'claim', '1', ',', 'wherein', 'said', 'feet', 'portion', '(', ')', 'and/or', 'said', 'hand', 'portion', '(', ')', 'comprised', 'substantially', 'water', 'resistant', 'water', 'proof', 'material', '.', '13', '.', 'A', 'sleeping', 'bag', 'claimed', 'claim', '1', ',', 'wherein', 'said', 'feet', 'portion', '(', ')', 'and/or', 'said', 'hand', 'portion', '(', ')', 'releasable', 'attachable', 'said', 'least', 'one', 'leg', 'portion', 'arm', 'portion', 'respectively', '.', '14', '.', 'A', 'sleeping', 'bag', 'claimed', 'claim', '1', 'wherein', 'said', 'least', 'one', 'leg', 'portion', 'provided', 'drawstring', 'enable', 'user', 'draw', 'said', 'least', 'one', 'leg', 'portion', 'around', 'his/her', 'leg', '.', '15', '.', 'A', 'sleeping', 'bag', 'claimed', 'claim', '14', 'wherein', 'said', 'drawstring', 'located', 'towards', 'lower', 'part', 'said', 'least', 'one', 'leg', 'portion', 'whereby', 'user', 'may', 'draw', 'said', 'least', 'one', 'leg', 'portion', 'around', 'his/her', 'lower', 'leg', '.', '16', '.', 'A', 'sleeping', 'bag', 'claimed', 'claim', '1', 'wherein', 'main', 'entry', 'sleeping', 'bag', 'provided', 'zip', 'fastener', 'running', 'substantially', 'len ...

# %%
#STEM 1 TXT FILE for unigrams
stemmed = []
text = tokens
for word in text:
    stemmed.append(stemmer.stem(word))
print stemmed
# Out:
# [u'~~', u'1', u'.', u'A', u'sleep', u'bag', u'includ', u':', u')', u'main', u'bodi', u'substanti', u'enclos', u'trunk', u'user', u',', u'b', u')', u'least', u'two', u'bodi', u'part', u'portion', u'commun', u',', u'attach', u'said', u'main', u'bodi', u',', u'said', u'least', u'two', u'bodi', u'part', u'portion', u'adapt', u'enclos', u',', u'partial', u'fulli', u',', u'least', u'one', u'bodi', u'part', u'user', u',', u'wherein', u'one', u'said', u'bodi', u'part', u'portion', u'includ', u'least', u'one', u'leg', u'portion', u'integr', u'form', u'main', u'bodi', u',', u'wherein', u'anoth', u'said', u'bodi', u'part', u'portion', u'includ', u'least', u'one', u'arm', u'portion', u'releas', u'attach', u'main', u'bodi', u'.', u'2', u'.', u'A', u'sleep', u'bag', u'claim', u'claim', u'1', u'wherein', u'said', u'least', u'two', u'bodi', u'part', u'portion', u'includ', u'head', u'portion', u'.', u'3', u'.', u'A', u'sleep', u'bag', u'claim', u'claim', u'2', u',', u'wherein', u'said', u'head', u'portion', u'releas', u'attach', u'main', u'bodi', u'.', u'4', u'.', u'A', u'sleep', u'bag', u'claim', u'claim', u'1', u',', u'wherein', u'provid', u'substanti', u'water', u'resist', u'water', u'proof', u'seal', u'said', u'main', u'bodi', u'releas', u'attach', u'bodi', u'part', u'portion', u'(', u')', u',', u'attach', u'.', u'5', u'.', u'A', u'sleep', u'bag', u'claim', u'claim', u'4', u'wherein', u'said', u'substanti', u'water', u'resist', u'water', u'proof', u'seal', u'form', u'provid', u'releas', u'sealabl', u'flap', u'provid', u'either', u'main', u'bodi', u'releas', u'attach', u'bodi', u'part', u'portion', u'(', u')', u',', u'region', u'attach', u'.', u'6', u'.', u'A', u'sleep', u'bag', u'claim', u'claim', u'1', u',', u'wherein', u'one', u'releas', u'attach', u'bodi', u'part', u'portion', u'(', u')', u'compris', u'differ', u'materi', u'(', u')', u'said', u'main', u'bodi', u'.', u'7', u'.', u'A', u'sleep', u'bag', u'claim', u'claim', u'1', u',', u'wherein', u'provid', u'gusset', u'region', u'least', u'two', u'leg', u'portion', u'meet', u'main', u'bodi', u'.', u'8', u'.', u'A', u'sleep', u'bag', u'claim', u'claim', u'1', u',', u'wherein', u'main', u'bodi', u'provid', u'drawstr', u'.', u'9', u'.', u'A', u'sleep', u'bag', u'claim', u'claim', u'1', u',', u'wherein', u'said', u'least', u'one', u'leg', u'portion', u'provid', u'feet', u'portion', u'(', u')', u'substanti', u'enclos', u'feet', u'user', u'.', u'10', u'.', u'A', u'sleep', u'bag', u'claim', u'claim', u'9', u',', u'wherein', u'said', u'feet', u'portion', u'(', u')', u'provid', u'drawstr', u'enabl', u'user', u'draw', u'feet', u'portion', u'(', u')', u'around', u'his/her', u'feet', u'lower', u'leg', u'.', u'11', u'.', u'A', u'sleep', u'bag', u'claim', u'claim', u'1', u',', u'wherein', u'said', u'least', u'one', u'arm', u'portion', u'provid', u'hand', u'portion', u'(', u')', u'substanti', u'enclos', u'hand', u'user', u'.', u'12', u'.', u'A', u'sleep', u'bag', u'claim', u'claim', u'1', u',', u'wherein', u'said', u'feet', u'portion', u'(', u')', u'and/or', u'said', u'hand', u'portion', u'(', u')', u'compris', u'substanti', u'water', u'resist', u'water', u'proof', u'materi', u'.', u'13', u'.', u'A', u'sleep', u'bag', u'claim', u'claim', u'1', u',', u'wherein', u'said', u'feet', u'portion', u'(', u')', u'and/or', u'said', u'hand', u'portion', u'(', u')', u'releas', u'attach', u'said', u'least', u'one', u'leg', u'portion', u'arm', u'portion', u'respect', u'.', u'14', u'.', u'A', u'sleep', u'bag', u'claim', u'claim', u'1', u'wherein', u'said', u'least', u'one', u'leg', u'portion', u'provid', u'drawstr', u'enabl', u'user', u'draw', u'said', u'least', u'one', u'leg', u'portion', u'around', u'his/her', u'leg', u'.', u'15', u'.', u'A', u'sleep', u'bag', u'claim', u'claim', u'14', u'wherein', u'said', u'drawstr', u'locat', u'toward', u'lower', u'part', u'said', u'least', u'one', u'leg', u'portion', u'wherebi', u'user', u'may', u'draw', u'said', u'least', u'one', u'leg', u'portion', u'around', u'his/her', u'lo ...

# %%
# MAKE DF OF STEMMED
stemmed_df = pd.DataFrame(stemmed, columns=['words'])
stemmed_df
# Out:
#           words
# 0            ~~
# 1             1
# 2             .
# 3             A
# 4        dispos
# 5       garment
# 6     protector
# 7       compris
# 8             :
# 9             )
# 10    protector
# 11        cover
# 12        front
# 13       surfac
# 14         back
# 15       surfac
# 16            ,
# 17        first
# 18         side
# 19       second
# 20         side
# 21            ,
# 22        first
# 23       second
# 24          end
# 25      support
# 26        first
# 27          end
# 28    protector
# 29      support
# ..          ...
# 615      bottom
# 616         end
# 617           ,
# 618       front
# 619        back
# 620        form
# 621        fold
# 622         one
# 623       first
# 624       close
# 625       posit
# 626      storag
# 627      second
# 628        open
# 629       posit
# 630         top
# 631         end
# 632        open
# 633       posit
# 634     collect
# 635    particul
# 636      liquid
# 637        move
# 638  downwardli
# 639       along
# 640       front
# 641      surfac
# 642   protector
# 643       cover
# 644           .
#
# [645 rows x 1 columns]

# %%
# COUNT OCCURRENCE OF UNIGRAMS
data = stemmed
count_uni = Counter()
for elem in data:
    count_uni[elem] += 1
countUNI = dict(count_uni)

# %%
# MAKE DF OF UNIGRAMS
countUNI_df = pd.DataFrame.from_dict(countUNI, orient='index')
countUNI_df
#EXPORT TO CSV
countUNI_df.to_csv(path_or_buf='/Users/jillschulze/Desktop/PS2/countUNI_6334221.csv')

# %% [markdown]
# Bigram and Trigram code snippets from "Locally Optimal" blog: http://locallyoptimal.com/blog/2013/01/20/elegant-n-gram-generation-in-python/. Another noteable option, though more complex, is from StackOverflow: http://stackoverflow.com/questions/21844546/forming-bigrams-of-words-in-list-of-sentences-python.

# %%
# BIGRAMS
input_list = stemmed

def find_bigrams(input_list):
  return zip(input_list, input_list[1:])

bigrams = zip(input_list, input_list[1:])
print bigrams
# Out:
# [(u'~~', u'1'), (u'1', u'.'), (u'.', u'A'), (u'A', u'dispos'), (u'dispos', u'garment'), (u'garment', u'protector'), (u'protector', u'compris'), (u'compris', u':'), (u':', u')'), (u')', u'protector'), (u'protector', u'cover'), (u'cover', u'front'), (u'front', u'surfac'), (u'surfac', u'back'), (u'back', u'surfac'), (u'surfac', u','), (u',', u'first'), (u'first', u'side'), (u'side', u'second'), (u'second', u'side'), (u'side', u','), (u',', u'first'), (u'first', u'second'), (u'second', u'end'), (u'end', u'support'), (u'support', u'first'), (u'first', u'end'), (u'end', u'protector'), (u'protector', u'support'), (u'support', u'posit'), (u'posit', u'cover'), (u'cover', u'front'), (u'front', u'portion'), (u'portion', u'chest'), (u'chest', u'stomach'), (u'stomach', u'user'), (u'user', u';'), (u';', u','), (u',', u'b'), (u'b', u')'), (u')', u'protector'), (u'protector', u'support'), (u'support', u'adapt'), (u'adapt', u'support'), (u'support', u'garment'), (u'garment', u'protector'), (u'protector', u'neck'), (u'neck', u'user'), (u'user', u'wherein'), (u'wherein', u'protector'), (u'protector', u'support'), (u'support', u'compris'), (u'compris', u'strap'), (u'strap', u'first'), (u'first', u'end'), (u'end', u'second'), (u'second', u'end'), (u'end', u'posit'), (u'posit', u'extend'), (u'extend', u'first'), (u'first', u'end'), (u'end', u'strap'), (u'strap', u'join'), (u'join', u'first'), (u'first', u'side'), (u'side', u'first'), (u'first', u'end'), (u'end', u'protector'), (u'protector', u'cover'), (u'cover', u'around'), (u'around', u'back'), (u'back', u'neck'), (u'neck', u'user'), (u'user', u'second'), (u'second', u'end'), (u'end', u'strip'), (u'strip', u'join'), (u'join', u'second'), (u'second', u'side'), (u'side', u'protector'), (u'protector', u'cover'), (u'cover', u'wherein'), (u'wherein', u'strap'), (u'strap', u'includ'), (u'includ', u'least'), (u'least', u'one'), (u'one', u'tearabl'), (u'tearabl', u'perfor'), (u'perfor', u'torn'), (u'torn', u'permit'), (u'permit', u'quick'), (u'quick', u'remov'), (u'remov', u'protector'), (u'protector', u'use'), (u'use', u'user'), (u'user', u';'), (u';', u'c'), (u'c', u')'), (u')', u'pouch'), (u'pouch', u'posit'), (u'posit', u'second'), (u'second', u'end'), (u'end', u'protector'), (u'protector', u'cover'), (u'cover', u','), (u',', u'pouch'), (u'pouch', u'top'), (u'top', u'end'), (u'end', u'bottom'), (u'bottom', u'end'), (u'end', u','), (u',', u'front'), (u'front', u'back'), (u'back', u'form'), (u'form', u'fold'), (u'fold', u'one'), (u'one', u'first'), (u'first', u'close'), (u'close', u'posit'), (u'posit', u'storag'), (u'storag', u'second'), (u'second', u'open'), (u'open', u'posit'), (u'posit', u'top'), (u'top', u'end'), (u'end', u'open'), (u'open', u'posit'), (u'posit', u'collect'), (u'collect', u'particul'), (u'particul', u'liquid'), (u'liquid', u'move'), (u'move', u'downwardli'), (u'downwardli', u'along'), (u'along', u'front'), (u'front', u'surfac'), (u'surfac', u'protector'), (u'protector', u'cover'), (u'cover', u'.'), (u'.', u'2'), (u'2', u'.'), (u'.', u'A'), (u'A', u'dispos'), (u'dispos', u'garment'), (u'garment', u'protector'), (u'protector', u'compris'), (u'compris', u':'), (u':', u')'), (u')', u'protector'), (u'protector', u'cover'), (u'cover', u'front'), (u'front', u'surfac'), (u'surfac', u'back'), (u'back', u'surfac'), (u'surfac', u','), (u',', u'first'), (u'first', u'side'), (u'side', u'second'), (u'second', u'side'), (u'side', u','), (u',', u'first'), (u'first', u'second'), (u'second', u'end'), (u'end', u'support'), (u'support', u'first'), (u'first', u'end'), (u'end', u'protector'), (u'protector', u'support'), (u'support', u'posit'), (u'posit', u'cover'), (u'cover', u'front'), (u'front', u'portion'), (u'portion', u'chest'), (u'chest', u'stomach'), (u'stomach', u'user'), (u'user', u';'), (u';', u','), (u',', u'b'), (u'b', u')'), (u')', u'protector'), (u'protector', u'support'), (u'support', u'adapt'), (u'adapt', u'support'), (u'support', u'garment'), (u'garment', u'protector'), (u'protector', u ...

# %%
# COUNT OCCURRENCE OF BIGRAMS
data = bigrams
count_bi = Counter()
for elem in data:
    count_bi[elem] += 1
dict(count_bi)
# Out:
# {(u')', u'neck'): 1,
#  (u')', u'pouch'): 4,
#  (u')', u'protector'): 7,
#  (u',', u'b'): 4,
#  (u',', u'first'): 12,
#  (u',', u'front'): 4,
#  (u',', u'pouch'): 4,
#  (u'.', u'2'): 1,
#  (u'.', u'3'): 1,
#  (u'.', u'4'): 1,
#  (u'.', u'A'): 4,
#  (u'1', u'.'): 1,
#  (u'2', u'.'): 1,
#  (u'3', u'.'): 1,
#  (u'4', u'.'): 1,
#  (u':', u')'): 4,
#  (u';', u','): 4,
#  (u';', u'c'): 4,
#  (u'A', u'dispos'): 4,
#  (u'adapt', u'support'): 3,
#  (u'adhes', u'section'): 6,
#  (u'along', u'front'): 4,
#  (u'around', u'back'): 2,
#  (u'b', u')'): 4,
#  (u'back', u'form'): 4,
#  (u'back', u'neck'): 2,
#  (u'back', u'surfac'): 4,
#  (u'bottom', u'end'): 4,
#  (u'c', u')'): 4,
#  (u'chang', u'length'): 2,
#  (u'chest', u'stomach'): 4,
#  (u'close', u'posit'): 4,
#  (u'collect', u'particul'): 4,
#  (u'compris', u':'): 4,
#  (u'compris', u'strap'): 2,
#  (u'compris', u'two'): 2,
#  (u'cover', u','): 4,
#  (u'cover', u'.'): 4,
#  (u'cover', u'around'): 2,
#  (u'cover', u'front'): 8,
#  (u'cover', u'second'): 4,
#  (u'cover', u'wherein'): 2,
#  (u'dispos', u'garment'): 4,
#  (u'downwardli', u'along'): 4,
#  (u'end', u','): 4,
#  (u'end', u'bottom'): 4,
#  (u'end', u'chang'): 2,
#  (u'end', u'first'): 2,
#  (u'end', u'includ'): 2,
#  (u'end', u'join'): 4,
#  (u'end', u'joinabl'): 2,
#  (u'end', u'open'): 4,
#  (u'end', u'portion'): 4,
#  (u'end', u'posit'): 2,
#  (u'end', u'produc'): 2,
#  (u'end', u'protector'): 14,
#  (u'end', u'second'): 4,
#  (u'end', u'strap'): 2,
#  (u'end', u'strip'): 2,
#  (u'end', u'support'): 4,
#  (u'extend', u'first'): 2,
#  (u'first', u'close'): 4,
#  (u'first', u'end'): 22,
#  (u'first', u'second'): 4,
#  (u'first', u'side'): 8,
#  (u'first', u'strap'): 8,
#  (u'fold', u'one'): 4,
#  (u'form', u'fold'): 4,
#  (u'form', u'strap'): 2,
#  (u'front', u'back'): 4,
#  (u'front', u'portion'): 4,
#  (u'front', u'surfac'): 8,
#  (u'garment', u'protector'): 7,
#  (u'includ', u'adhes'): 2,
#  (u'includ', u'least'): 4,
#  (u'join', u'first'): 4,
#  (u'join', u'second'): 4,
#  (u'joinabl', u'adhes'): 2,
#  (u'joinabl', u'form'): 2,
#  (u'least', u'one'): 5,
#  (u'length', u'strap'): 2,
#  (u'liquid', u'move'): 4,
#  (u'move', u'downwardli'): 4,
#  (u'neck', u'user'): 7,
#  (u'one', u'adhes'): 1,
#  (u'one', u'first'): 4,
#  (u'one', u'tearabl'): 4,
#  (u'open', u'posit'): 8,
#  (u'particul', u'liquid'): 4,
#  (u'perfor', u'adhes'): 1,
#  (u'perfor', u'least'): 1,
#  (u'perfor', u'torn'): 4,
#  (u'permit', u'quick'): 1,
#  (u'permit', u'remov'): 1,
#  (u'portion', u'chest'): 4,
#  (u'portion', u'first'): 2,
#  (u'portion', u'second'): 2,
#  (u'posit', u'collect'): 4,
#  (u'posit', u'cover'): 4,
#  (u'posit', u'extend'): 2,
#  (u'posit', u'second'): 4,
#  (u'posit', u'storag'): 4,
#  (u'posit', u'strap'): 2,
#  (u'posit', u'top'): 4,
#  (u'pouch', u'posit'): 4,
#  (u'pouch', u'top'): 4,
#  (u'produc', u'second'): 2,
#  (u'protector', u'compris'): 4,
#  (u'protector', u'cover'): 20,
#  (u'protector', u'neck'): 4,
#  (u'protector', u'support'): 11,
#  (u'protector', u'use'): 1,
#  (u'quick', u'remov'): 1,
#  (u'remov', u'protector'): 2,
#  (u'second', u'end'): 16,
#  (u'second', u'open'): 4,
#  (u'second', u'side'): 8,
#  (u'second', u'strap'): 8,
#  (u'section', u','): 2,
#  (u'section', u';'): 1,
#  (u'section', u'first'): 8,
#  (u'section', u'includ'): 1,
#  (u'section', u'joinabl'): 2,
#  (u'section', u'posit'): 2,
#  (u'section', u'second'): 2,
#  (u'section', u'tear'): 4,
#  (u'section', u'tearabl'): 1,
#  (u'side', u','): 4,
#  (u'side', u'first'): 6,
#  (u'side', u'protector'): 2,
#  (u'side', u'second'): 4,
#  (u'stomach', u'user'): 4,
#  (u'storag', u'second'): 4,
#  (u'strap', u';'): 1,
#  (u'strap', u'first'): 2,
#  (u'strap', u'includ'): 3,
#  (u'strap', u'join'): 2,
#  (u'strap', u'section'): 17,
#  (u'strap', u'tear'): 4,
#  (u'strap', u'tearabl'): 1,
#  (u'strap', u'wherein'): 2,
#  (u'strip', u'join'): 2,
#  (u'support', u'adapt'): 3,
#  (u'support', u'compris'): 4,
#  (u'support', u'first'): 4,
#  (u'support', u'garment'): 3,
#  (u'support', u'posit'): 4,
#  (u'surfac', u','): 4,
#  (u'surfac', u'back'): 4,
#  (u'surfac', u'protector'): 4,
#  (u'tear', u'end'): 8,
#  (u'tearabl', u'perfor'): 6,
#  (u'top', u'end'): 8,
#  (u'torn', u','): 2,
#  (u'torn', u'permit'): 2,
#  (u'two', u'strap'): 2,
#  (u'use', u'user'): 1,
#  (u'user', u';'): 6,
#  (u'user', u'second'): 2,
#  (u'user', u'wherein'): 4,
#  (u'wherein', u'protector'): 4,
#  (u'wherein', u'strap'): 4,
#  (u'~~', u'1'): 1}

# %%
# MAKE DF OF BIGRAMS
countBI_df = pd.DataFrame.from_dict(count_bi, orient='index')
countBI_df

#EXPORT TO CSV
countBI_df.to_csv(path_or_buf='/Users/jillschulze/Desktop/PS2/countBI_6334221.csv')

# %%
# TRIGRAMS
input_list = stemmed

def find_ngrams(input_list, n):
  return zip(*[input_list[i:] for i in range(n)])

trigrams = zip(input_list, input_list[1:], input_list[2:])
print(trigrams)
# Out:
# [(u'~~', u'1', u'.'), (u'1', u'.', u'A'), (u'.', u'A', u'dispos'), (u'A', u'dispos', u'garment'), (u'dispos', u'garment', u'protector'), (u'garment', u'protector', u'compris'), (u'protector', u'compris', u':'), (u'compris', u':', u')'), (u':', u')', u'protector'), (u')', u'protector', u'cover'), (u'protector', u'cover', u'front'), (u'cover', u'front', u'surfac'), (u'front', u'surfac', u'back'), (u'surfac', u'back', u'surfac'), (u'back', u'surfac', u','), (u'surfac', u',', u'first'), (u',', u'first', u'side'), (u'first', u'side', u'second'), (u'side', u'second', u'side'), (u'second', u'side', u','), (u'side', u',', u'first'), (u',', u'first', u'second'), (u'first', u'second', u'end'), (u'second', u'end', u'support'), (u'end', u'support', u'first'), (u'support', u'first', u'end'), (u'first', u'end', u'protector'), (u'end', u'protector', u'support'), (u'protector', u'support', u'posit'), (u'support', u'posit', u'cover'), (u'posit', u'cover', u'front'), (u'cover', u'front', u'portion'), (u'front', u'portion', u'chest'), (u'portion', u'chest', u'stomach'), (u'chest', u'stomach', u'user'), (u'stomach', u'user', u';'), (u'user', u';', u','), (u';', u',', u'b'), (u',', u'b', u')'), (u'b', u')', u'protector'), (u')', u'protector', u'support'), (u'protector', u'support', u'adapt'), (u'support', u'adapt', u'support'), (u'adapt', u'support', u'garment'), (u'support', u'garment', u'protector'), (u'garment', u'protector', u'neck'), (u'protector', u'neck', u'user'), (u'neck', u'user', u'wherein'), (u'user', u'wherein', u'protector'), (u'wherein', u'protector', u'support'), (u'protector', u'support', u'compris'), (u'support', u'compris', u'strap'), (u'compris', u'strap', u'first'), (u'strap', u'first', u'end'), (u'first', u'end', u'second'), (u'end', u'second', u'end'), (u'second', u'end', u'posit'), (u'end', u'posit', u'extend'), (u'posit', u'extend', u'first'), (u'extend', u'first', u'end'), (u'first', u'end', u'strap'), (u'end', u'strap', u'join'), (u'strap', u'join', u'first'), (u'join', u'first', u'side'), (u'first', u'side', u'first'), (u'side', u'first', u'end'), (u'first', u'end', u'protector'), (u'end', u'protector', u'cover'), (u'protector', u'cover', u'around'), (u'cover', u'around', u'back'), (u'around', u'back', u'neck'), (u'back', u'neck', u'user'), (u'neck', u'user', u'second'), (u'user', u'second', u'end'), (u'second', u'end', u'strip'), (u'end', u'strip', u'join'), (u'strip', u'join', u'second'), (u'join', u'second', u'side'), (u'second', u'side', u'protector'), (u'side', u'protector', u'cover'), (u'protector', u'cover', u'wherein'), (u'cover', u'wherein', u'strap'), (u'wherein', u'strap', u'includ'), (u'strap', u'includ', u'least'), (u'includ', u'least', u'one'), (u'least', u'one', u'tearabl'), (u'one', u'tearabl', u'perfor'), (u'tearabl', u'perfor', u'torn'), (u'perfor', u'torn', u'permit'), (u'torn', u'permit', u'quick'), (u'permit', u'quick', u'remov'), (u'quick', u'remov', u'protector'), (u'remov', u'protector', u'use'), (u'protector', u'use', u'user'), (u'use', u'user', u';'), (u'user', u';', u'c'), (u';', u'c', u')'), (u'c', u')', u'pouch'), (u')', u'pouch', u'posit'), (u'pouch', u'posit', u'second'), (u'posit', u'second', u'end'), (u'second', u'end', u'protector'), (u'end', u'protector', u'cover'), (u'protector', u'cover', u','), (u'cover', u',', u'pouch'), (u',', u'pouch', u'top'), (u'pouch', u'top', u'end'), (u'top', u'end', u'bottom'), (u'end', u'bottom', u'end'), (u'bottom', u'end', u','), (u'end', u',', u'front'), (u',', u'front', u'back'), (u'front', u'back', u'form'), (u'back', u'form', u'fold'), (u'form', u'fold', u'one'), (u'fold', u'one', u'first'), (u'one', u'first', u'close'), (u'first', u'close', u'posit'), (u'close', u'posit', u'storag'), (u'posit', u'storag', u'second'), (u'storag', u'second', u'open'), (u'second', u'open', u'posit'), (u'open', u'posit', u'top'), (u'posit', u'top', u'end'), (u'top', u'end', u'open'), (u'end', u'open', u'posit'), (u'open', u'posit', u'collect'), (u'posit', u'collect', u' ...

# %%
# COUNT OCCURRENCE OF TRIGRAMS
data = trigrams
count_tri = Counter()
for elem in data:
    count_tri[elem] += 1
dict(count_tri)
# Out:
# {(u')', u'neck', u'user'): 1,
#  (u')', u'pouch', u'posit'): 4,
#  (u')', u'protector', u'cover'): 4,
#  (u')', u'protector', u'support'): 3,
#  (u',', u'b', u')'): 4,
#  (u',', u'first', u'second'): 4,
#  (u',', u'first', u'side'): 4,
#  (u',', u'first', u'strap'): 4,
#  (u',', u'front', u'back'): 4,
#  (u',', u'pouch', u'top'): 4,
#  (u'.', u'2', u'.'): 1,
#  (u'.', u'3', u'.'): 1,
#  (u'.', u'4', u'.'): 1,
#  (u'.', u'A', u'dispos'): 4,
#  (u'1', u'.', u'A'): 1,
#  (u'2', u'.', u'A'): 1,
#  (u'3', u'.', u'A'): 1,
#  (u'4', u'.', u'A'): 1,
#  (u':', u')', u'protector'): 4,
#  (u';', u',', u'b'): 4,
#  (u';', u'c', u')'): 4,
#  (u'A', u'dispos', u'garment'): 4,
#  (u'adapt', u'support', u'garment'): 3,
#  (u'adhes', u'section', u'first'): 2,
#  (u'adhes', u'section', u'posit'): 2,
#  (u'adhes', u'section', u'second'): 2,
#  (u'along', u'front', u'surfac'): 4,
#  (u'around', u'back', u'neck'): 2,
#  (u'b', u')', u'neck'): 1,
#  (u'b', u')', u'protector'): 3,
#  (u'back', u'form', u'fold'): 4,
#  (u'back', u'neck', u'user'): 2,
#  (u'back', u'surfac', u','): 4,
#  (u'bottom', u'end', u','): 4,
#  (u'c', u')', u'pouch'): 4,
#  (u'chang', u'length', u'strap'): 2,
#  (u'chest', u'stomach', u'user'): 4,
#  (u'close', u'posit', u'storag'): 4,
#  (u'collect', u'particul', u'liquid'): 4,
#  (u'compris', u':', u')'): 4,
#  (u'compris', u'strap', u'first'): 2,
#  (u'compris', u'two', u'strap'): 2,
#  (u'cover', u',', u'pouch'): 4,
#  (u'cover', u'.', u'2'): 1,
#  (u'cover', u'.', u'3'): 1,
#  (u'cover', u'.', u'4'): 1,
#  (u'cover', u'around', u'back'): 2,
#  (u'cover', u'front', u'portion'): 4,
#  (u'cover', u'front', u'surfac'): 4,
#  (u'cover', u'second', u'end'): 4,
#  (u'cover', u'wherein', u'strap'): 2,
#  (u'dispos', u'garment', u'protector'): 4,
#  (u'downwardli', u'along', u'front'): 4,
#  (u'end', u',', u'front'): 4,
#  (u'end', u'bottom', u'end'): 4,
#  (u'end', u'chang', u'length'): 2,
#  (u'end', u'first', u'end'): 2,
#  (u'end', u'includ', u'adhes'): 2,
#  (u'end', u'join', u'first'): 2,
#  (u'end', u'join', u'second'): 2,
#  (u'end', u'joinabl', u'adhes'): 2,
#  (u'end', u'open', u'posit'): 4,
#  (u'end', u'portion', u'first'): 2,
#  (u'end', u'portion', u'second'): 2,
#  (u'end', u'posit', u'extend'): 2,
#  (u'end', u'produc', u'second'): 2,
#  (u'end', u'protector', u'cover'): 10,
#  (u'end', u'protector', u'support'): 4,
#  (u'end', u'second', u'end'): 2,
#  (u'end', u'second', u'strap'): 2,
#  (u'end', u'strap', u'join'): 2,
#  (u'end', u'strip', u'join'): 2,
#  (u'end', u'support', u'first'): 4,
#  (u'extend', u'first', u'end'): 2,
#  (u'first', u'close', u'posit'): 4,
#  (u'first', u'end', u'first'): 2,
#  (u'first', u'end', u'join'): 4,
#  (u'first', u'end', u'portion'): 2,
#  (u'first', u'end', u'protector'): 10,
#  (u'first', u'end', u'second'): 2,
#  (u'first', u'end', u'strap'): 2,
#  (u'first', u'second', u'end'): 4,
#  (u'first', u'side', u'first'): 4,
#  (u'first', u'side', u'second'): 4,
#  (u'first', u'strap', u'section'): 6,
#  (u'first', u'strap', u'tear'): 2,
#  (u'fold', u'one', u'first'): 4,
#  (u'form', u'fold', u'one'): 4,
#  (u'form', u'strap', u'wherein'): 2,
#  (u'front', u'back', u'form'): 4,
#  (u'front', u'portion', u'chest'): 4,
#  (u'front', u'surfac', u'back'): 4,
#  (u'front', u'surfac', u'protector'): 4,
#  (u'garment', u'protector', u'compris'): 4,
#  (u'garment', u'protector', u'neck'): 3,
#  (u'includ', u'adhes', u'section'): 2,
#  (u'includ', u'least', u'one'): 4,
#  (u'join', u'first', u'side'): 4,
#  (u'join', u'second', u'side'): 4,
#  (u'joinabl', u'adhes', u'section'): 2,
#  (u'joinabl', u'form', u'strap'): 2,
#  (u'least', u'one', u'adhes'): 1,
#  (u'least', u'one', u'tearabl'): 4,
#  (u'length', u'strap', u';'): 1,
#  (u'length', u'strap', u'section'): 1,
#  (u'liquid', u'move', u'downwardli'): 4,
#  (u'move', u'downwardli', u'along'): 4,
#  (u'neck', u'user', u';'): 1,
#  (u'neck', u'user', u'second'): 2,
#  (u'neck', u'user', u'wherein'): 4,
#  (u'one', u'adhes', u'section'): 1,
#  (u'one', u'first', u'close'): 4,
#  (u'one', u'tearabl', u'perfor'): 4,
#  (u'open', u'posit', u'collect'): 4,
#  (u'open', u'posit', u'top'): 4,
#  (u'particul', u'liquid', u'move'): 4,
#  (u'perfor', u'adhes', u'section'): 1,
#  (u'perfor', u'least', u'one'): 1,
#  (u'perfor', u'torn', u','): 2,
#  (u'perfor', u'torn', u'permit'): 2,
#  (u'permit', u'quick', u'remov'): 1,
#  (u'permit', u'remov', u'protector'): 1,
#  (u'portion', u'chest', u'stomach'): 4,
#  (u'portion', u'first', u'strap'): 2,
#  (u'portion', u'second', u'strap'): 2,
#  (u'posit', u'collect', u'particul'): 4,
#  (u'posit', u'cover', u'front'): 4,
#  (u'posit', u'extend', u'first'): 2,
#  (u'posit', u'second', u'end'): 4,
#  (u'posit', u'storag', u'second'): 4,
#  (u'posit', u'strap', u'section'): 1,
#  (u'posit', u'strap', u'tearabl'): 1,
#  (u'posit', u'top', u'end'): 4,
#  (u'pouch', u'posit', u'second'): 4,
#  (u'pouch', u'top', u'end'): 4,
#  (u'produc', u'second', u'strap'): 2,
#  (u'protector', u'compris', u':'): 4,
#  (u'protector', u'cover', u','): 4,
#  (u'protector', u'cover', u'.'): 4,
#  (u'protector', u'cover', u'around'): 2,
#  (u'protector', u'cover', u'front'): 4,
#  (u'protector', u'cover', u'second'): 4,
#  (u'protector', u'cover', u'wherein'): 2,
#  (u'protector', u'neck', u'user'): 4,
#  (u'protector', u'support', u'adapt'): 3,
#  (u'protector', u'support', u'compris'): 4,
#  (u'protector', u'support', u'posit'): 4,
#  (u'protector', u'use', u'user'): 1,
#  (u'quick', u'remov', u'protector'): 1,
#  (u'remov', u'protector', u'neck'): 1,
#  (u'remov', u'protector', u'use'): 1,
#  (u'second', u'end', u'portion'): 2,
#  (u'second', u'end', u'posit'): 2,
#  (u'second', u'end', u'protector'): 4,
#  (u'second', u'end', u'second'): 2,
#  (u'second', u'end', u'strip'): 2,
#  (u'second', u'end', u'support'): 4,
#  (u'second', u'open', u'posit'): 4,
#  (u'second', u'side', u','): 4,
#  (u'second', u'side', u'first'): 2,
#  (u'second', u'side', u'protector'): 2,
#  (u'second', u'strap', u'section'): 6,
#  (u'second', u'strap', u'tear'): 2,
#  (u'section', u',', u'first'): 2,
#  (u'section', u';', u'c'): 1,
#  (u'section', u'first', u'end'): 6,
#  (u'section', u'first', u'strap'): 2,
#  (u'section', u'includ', u'least'): 1,
#  (u'section', u'joinabl', u'form'): 2,
#  (u'section', u'posit', u'strap'): 2,
#  (u'section', u'second', u'strap'): 2,
#  (u'section', u'tear', u'end'): 4,
#  (u'section', u'tearabl', u'perfor'): 1,
#  (u'side', u',', u'first'): 4,
#  (u'side', u'first', u'end'): 6,
#  (u'side', u'protector', u'cover'): 2,
#  (u'side', u'second', u'side'): 4,
#  (u'stomach', u'user', u';'): 4,
#  (u'storag', u'second', u'open'): 4,
#  (u'strap', u';', u'c'): 1,
#  (u'strap', u'first', u'end'): 2,
#  (u'strap', u'includ', u'least'): 3,
#  (u'strap', u'join', u'first'): 2,
#  (u'strap', u'section', u','): 2,
#  (u'strap', u'section', u';'): 1,
#  (u'strap', u'section', u'first'): 6,
#  (u'strap', u'section', u'includ'): 1,
#  (u'strap', u'section', u'joinabl'): 2,
#  (u'strap', u'section', u'tear'): 4,
#  (u'strap', u'section', u'tearabl'): 1,
#  (u'strap', u'tear', u'end'): 4,
#  (u'strap', u'tearabl', u'perfor'): 1,
#  (u'strap', u'wherein', u'strap'): 2,
#  (u'strip', u'join', u'second'): 2,
#  (u'support', u'adapt', u'support'): 3,
#  (u'support', u'compris', u'strap'): 2,
#  (u'support', u'compris', u'two'): 2,
#  (u'support', u'first', u'end'): 4,
#  (u'support', u'garment', u'protector'): 3,
#  (u'support', u'posit', u'cover'): 4,
#  (u'surfac', u',', u'first'): 4,
#  (u'surfac', u'back', u'surfac'): 4,
#  (u'surfac', u'protector', u'cover'): 4,
#  (u'tear', u'end', u'chang'): 2,
#  (u'tear', u'end', u'includ'): 2,
#  (u'tear', u'end', u'joinabl'): 2,
#  (u'tear', u'end', u'produc'): 2,
#  (u'tearabl', u'perfor', u'adhes'): 1,
#  (u'tearabl', u'perfor', u'least'): 1,
#  (u'tearabl', u'perfor', u'torn'): 4,
#  (u'top', u'end', u'bottom'): 4,
#  (u'top', u'end', u'open'): 4,
#  (u'torn', u',', u'first'): 2,
#  (u'torn', u'permit', u'quick'): 1,
#  (u'torn', u'permit', u'remov'): 1,
#  (u'two', u'strap', u'section'): 2,
#  (u'use', u'user', u';'): 1,
#  (u'user', u';', u','): 4,
#  (u'user', u';', u'c'): 2,
#  (u'user', u'second', u'end'): 2,
#  (u'user', u'wherein', u'protector'): 4,
#  (u'wherein', u'protector', u'support'): 4,
#  (u'wherein', u'strap', u'includ'): 3,
#  (u'wherein', u'strap', u'section'): 1,
#  (u'~~', u'1', u'.'): 1}

# %%
# MAKE DF OF BIGRAMS
countTRI_df = pd.DataFrame.from_dict(count_tri, orient='index')
countTRI_df

#EXPORT TO CSV
countTRI_df.to_csv(path_or_buf='/Users/jillschulze/Desktop/PS2/countTRI_6334221.csv')

# %%
# MAKE SUMMARY DF FOR ALL NGRAMS
df = pd.DataFrame()
summary_6334220_df = df.append([countUNI_df, countBI_df, countTRI_df])

#EXPORT TO CSV
summary_6334220_df.to_csv(path_or_buf='/Users/jillschulze/Desktop/PS2/summary_6334221.csv')
